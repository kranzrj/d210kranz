# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy` (or `python3.12 -m pip install spacy`)
# * We need the **pandas** library to make dataframes: `pip install pandas` (or `python3.12 -m pip install pandas`)
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
# nlp = spacy.cli.download("en_core_web_lg")

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = 'texts/ferris'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.
# Out:
# ferris
# 206636

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# ferris
# " ----> PUNCT ::::: "
# FERRIS ----> PROPN ::::: FERRIS
# BUELLER ----> PROPN ::::: BUELLER
# 'S ----> PART ::::: 's
# DAY ----> PROPN ::::: DAY
# OFF ----> PROPN ::::: OFF
# " ----> PUNCT ::::: "
#
#
#                                       ----> SPACE :::::
#
#
# by ----> ADP ::::: by
#
#
#                                  ----> SPACE :::::
#
#
# John ----> PROPN ::::: John
# Hughes ----> PROPN ::::: Hughes
#
#
# 						 ----> SPACE :::::
#
#
# SHOOTING ----> PROPN ::::: SHOOTING
# SCRIPT ----> NOUN ::::: script
#
# 						 ----> SPACE :::::
#
# July ----> PROPN ::::: July
# 24 ----> NUM ::::: 24
# , ----> PUNCT ::::: ,
# 1985 ----> NUM ::::: 1985
#
#
#
#                           ----> SPACE :::::
#
#
#
# " ----> PUNCT ::::: "
# FERRIS ----> PROPN ::::: FERRIS
# BUELLER ----> PROPN ::::: BUELLER
# 'S ----> PART ::::: 's
# DAY ----> PROPN ::::: DAY
# OFF ----> PROPN ::::: OFF
# " ----> PUNCT ::::: "
#
#
#    ----> SPACE :::::
#
#
# 1 ----> NUM ::::: 1
#   ----> SPACE :::::
# BLACK ----> ADJ ::::: black
# SCREEN ----> PROPN ::::: SCREEN
#                                                   ----> SPACE :::::
# 1 ----> NUM ::::: 1
#
#
#       ----> SPACE :::::
#
#
# MAIN ----> PROPN ::::: MAIN
# TITLES ----> PROPN ::::: TITLES
#
#
#       ----> SPACE :::::
#
#
# IT ----> PRON ::::: it
# 'S ----> AUX ::::: be
# SILENT ----> ADJ ::::: silent
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# BEAT ----> PROPN ::::: BEAT
# ... ----> PUNCT ::::: ...
# AND ----> CCONJ ::::: and
# AN ----> DET ::::: an
# EXPLOSION ----> NOUN ::::: explosion
# OF ----> ADP ::::: of
# SOUND ----> PROPN ::::: SOUND
# . ----> PUNCT ::::: .
#   ----> SPACE :::::
# A ----> DET ::::: a
# HOUSEHOLD ----> NOUN ::::: household
#
#       ----> SPACE :::::
#
# IN ----> ADP ::::: in
# THE ----> DET ::::: the
# MORNING ----> NOUN ::::: morning
# . ----> PUNCT ::::: .
# KIDS ----> PROPN ::::: KIDS
# GETTING ----> VERB ::::: get
# READY ----> ADJ ::::: ready
# FOR ----> ADP ::::: for
# SCHOOL ----> PROPN ::::: SCHOOL
# . ----> PUNCT ::::: .
# CLOCK ----> PROPN ::::: CLOCK
# RADIOS ----> PROPN ::::: RADIOS
# . ----> PUNCT ::::: .
#
#       ----> SPACE :::::
#
# KITCHEN ----> PROPN ::::: KITCHEN
# APPLIANCES ----> PROPN ::::: APPLIANCES
# . ----> PUNCT ::::: .
# SHOWERS ----> NOUN ::::: shower
# . ----> PUNCT ::::: .
# FIGHTING ----> NOUN ::::: fighting
# . ----> PUNCT ::::: .
# PEOPLE ----> NOUN ::::: PEOPLE
# YELLING ----> PROPN ::::: YELLING
# . ----> PUNCT ::::: .
# DOG ----> NOUN ::::: dog
#
#       ----> SPACE :::::
#
# BARKING ----> PROPN ::::: BARKING
# . ----> PUNCT ::::: .
# APPLIANCES ----> NOUN ::::: appliance
# BUZZING ----> NOUN ::::: buzzing
# . ----> PUNCT ::::: .
# CAR ----> NOUN ::::: car
# HORNS ----> PROPN ::::: HORNS
# . ----> PUNCT ::::: .
# IT ----> PRON ::::: it
# SOUNDS ----> VERB ::::: sound
# JUST ----> ADV ::::: just
# LIKE ----> SCONJ ::::: like
#
#       ----> SPACE :::::
#
# YOUR ----> PRON ::::: your
# HOUSE ----> PROPN ::::: HOUSE
# DID ----> VERB ::::: do
# . ----> PUNCT ::::: .
# STREAMS ----> ADV ::::: streams
# OF ----> ADP ::::: of
# ROCK'N ----> PROPN ::::: ROCK'N
# ROLL ----> NOUN ::::: roll
# FADE ----> VERB ::::: fade
# IN ----> ADV ::::: in
# AND ----> CCONJ ::::: and
# OUT ----> PROPN ::::: OUT
# . ----> PUNCT ::::: .
# HUEY ----> PROPN ::::: HUEY
#
#       ----> SPACE :::::
#
# LEWIS ----> PROPN ::::: LEWIS
# TO ----> ADP ::::: to
# LIONEL ----> PROPN ::::: LIONEL
# RITCHIE ----> PROPN ::::: RITCHIE
# TO ----> ADP ::::: to
# HUSKER ----> PROPN ::::: HUSKER
# DU ----> PROPN ::::: DU
# . ----> PUNCT ::::: .
# SURROUND ----> VERB ::::: surround
# MAKES ----> VERB ::::: make
# IT ----> PRON ::::: it
# FEEL ----> VERB ::::: feel
#
#       ----> SPACE :::::
#
# LIKE ----> ADP ::::: like
# YOU'RE ----> NOUN ::::: you're
# IN ----> ADP ::::: in
# THE ----> DET ::::: the
# ROOM ----> NOUN ::::: room
# . ----> PUNCT ::::: .
# AN ----> DET ::::: an
# AURAL ----> ADJ ::::: aural
# TOUR ----> NOUN ::::: tour
# OF ----> ADP ::::: of
# A ----> DET ::::: a
# HOUSE ----> PROPN ::::: HOUSE
# ON ----> PROPN ::::: ON
# A ----> PROPN ::::: A
#
#       ----> SPACE :::::
#
# SCHOOL ----> PROPN ::::: SCHOOL
# MORNING ----> NOUN ::::: morning
# . ----> PUNCT ::::: .
# BEGINING ----> PROPN ::::: BEGINING
# IN ----> ADP ::::: in
# THE ----> DET ::::: the
# KITCHEN ----> PROPN ::::: KITCHEN
# AND ----> CCONJ ::::: and
# MOVING ----> PROPN ::::: MOVING
# UPSTAIRS ----> PROPN ::::: UPSTAIRS
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FATHER ----> PROPN ::::: FATHER
# 'S ----> PART ::::: 's
# VOICE ----> NOUN ::::: voice
# ( ----> PUNCT ::::: (
# TOM ----> PROPN ::::: TOM
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Where ----> SCONJ ::::: where
# 's ----> AUX ::::: be
# my ----> PRON ::::: my
# wallet ----> NOUN ::::: wallet
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# SEVEN ----> NUM ::::: seven
# YEAR ----> NOUN ::::: year
# OLD ----> ADJ ::::: old
# BOY ----> NOUN ::::: boy
# ( ----> PUNCT ::::: (
# TODD ----> PROPN ::::: TODD
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# YOU ----> PRON ::::: you
# IDIOT ----> PROPN ::::: IDIOT
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TWELVE ----> NUM ::::: twelve
# YEAR ----> NOUN ::::: year
# OLD ----> ADJ ::::: old
# GIRL ----> NOUN ::::: girl
# ( ----> PUNCT ::::: (
# KIMBERLY ----> PROPN ::::: KIMBERLY
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# MOM ----> PROPN ::::: MOM
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# SHUT ----> PROPN ::::: SHUT
# - ----> PUNCT ::::: -
# UP ----> PROPN ::::: UP
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# EIGHTEEN ----> NUM ::::: eighteen
# YEAR ----> NOUN ::::: year
# OLD ----> ADJ ::::: old
# GIRL ----> NOUN ::::: girl
# ( ----> PUNCT ::::: (
# JEANIE ----> PROPN ::::: JEANIE
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# NEED ----> VERB ::::: need
# A ----> DET ::::: a
# TOWEL ----> PROPN ::::: TOWEL
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# JOYCE ----> PROPN ::::: JOYCE
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# whispers ----> VERB ::::: whisper
# , ----> PUNCT ::::: ,
# sadistic ----> ADJ ::::: sadistic
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# When ----> SCONJ ::::: when
# you ----> PRON ::::: you
# turn ----> VERB ::::: turn
# ten ----> NUM ::::: ten
# , ----> PUNCT ::::: ,
# your ----> PRON ::::: your
# head ----> NOUN ::::: head
# 's ----> AUX ::::: 's
# going ----> VERB ::::: go
#
#                 ----> SPACE :::::
#
# to ----> PART ::::: to
# swell ----> VERB ::::: swell
# up ----> ADP ::::: up
# real ----> ADV ::::: real
# big ----> ADJ ::::: big
# like ----> ADP ::::: like
# a ----> DET ::::: a
# watermelon ----> NOUN ::::: watermelon
#
#                 ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# we ----> PRON ::::: we
# 're ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# have ----> VERB ::::: have
# to ----> PART ::::: to
# put ----> VERB ::::: put
# you ----> PRON ::::: you
#
#                 ----> SPACE :::::
#
# to ----> PART ::::: to
# sleep ----> VERB ::::: sleep
# like ----> SCONJ ::::: like
# they ----> PRON ::::: they
# do ----> VERB ::::: do
# with ----> ADP ::::: with
# a ----> DET ::::: a
# dog ----> NOUN ::::: dog
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# MOM ----> PROPN ::::: MOM
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# JOYCE ----> PROPN ::::: JOYCE
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# WHO ----> PRON ::::: who
# PISSED ----> ADV ::::: pissed
# ON ----> ADP ::::: on
# THE ----> DET ::::: the
# TOILET ----> PROPN ::::: TOILET
# SEAT ----> PROPN ::::: SEAT
# ! ----> PUNCT ::::: !
# ? ----> PUNCT ::::: ?
# MOTHER ----> PROPN ::::: MOTHER
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Where ----> SCONJ ::::: where
# 's ----> AUX ::::: be
# Mom ----> PROPN ::::: Mom
# ? ----> SYM ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# Is ----> AUX ::::: be
# my ----> PRON ::::: my
# head ----> NOUN ::::: head
# going ----> VERB ::::: go
# to ----> PART ::::: to
# swell ----> VERB ::::: swell
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# OH ----> PROPN ::::: OH
# , ----> PUNCT ::::: ,
# MY ----> PROPN ::::: MY
# GOD ----> PROPN ::::: GOD
# ! ----> PUNCT ::::: !
# THE ----> DET ::::: the
# TOILET ----> PROPN ::::: TOILET
# PAPER ----> PROPN ::::: PAPER
# 'S ----> AUX ::::: be
# ALL ----> DET ::::: all
# WET ----> PROPN ::::: WET
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# MOTHER ----> PROPN ::::: MOTHER
# ( ----> PUNCT ::::: (
# JOYCE ----> PROPN ::::: JOYCE
# ) ----> PUNCT ::::: )
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# screams ----> VERB ::::: scream
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# TOM ----> PROPN ::::: TOM
# ! ----> PUNCT ::::: !
#
#
#       ----> SPACE :::::
#
#
# The ----> DET ::::: the
# house ----> NOUN ::::: house
# falls ----> VERB ::::: fall
# dead ----> ADV ::::: dead
# SILENT ----> ADJ ::::: silent
# . ----> PUNCT ::::: .
# We ----> PRON ::::: we
# hear ----> VERB ::::: hear
# footsteps ----> NOUN ::::: footstep
# thundering ----> VERB ::::: thunder
#
#       ----> SPACE :::::
#
# through ----> ADP ::::: through
# the ----> DET ::::: the
# house ----> NOUN ::::: house
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# TENSE ----> ADJ ::::: tense
# STRAIN ----> NOUN ::::: strain
# OF ----> ADP ::::: of
# MUSIC ----> NOUN ::::: music
# FADES ----> VERB ::::: fade
# UP ----> ADP ::::: up
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# Wait ----> PROPN ::::: Wait
# ! ----> PUNCT ::::: !
# Hold ----> VERB ::::: hold
# still ----> ADV ::::: still
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# You ----> PRON ::::: you
# heads ----> NOUN ::::: head
# starting ----> VERB ::::: start
# to ----> PART ::::: to
# swell ----> VERB ::::: swell
# up ----> ADP ::::: up
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#
#       ----> SPACE :::::
#
#
# Todd ----> PROPN ::::: Todd
# screams ----> VERB ::::: scream
# . ----> PUNCT ::::: .
# We ----> PRON ::::: we
# hear ----> VERB ::::: hear
# the ----> DET ::::: the
# sound ----> NOUN ::::: sound
# of ----> ADP ::::: of
# Tom ----> PROPN ::::: Tom
# 's ----> PART ::::: 's
# footsteps ----> NOUN ::::: footstep
# running ----> VERB ::::: run
#
#       ----> SPACE :::::
#
# through ----> ADP ::::: through
# the ----> DET ::::: the
# kitchen ----> NOUN ::::: kitchen
# , ----> PUNCT ::::: ,
# down ----> ADP ::::: down
# the ----> DET ::::: the
# hall ----> NOUN ::::: hall
# , ----> PUNCT ::::: ,
# up ----> ADP ::::: up
# the ----> DET ::::: the
# stairs ----> NOUN ::::: stair
# , ----> PUNCT ::::: ,
# up ----> ADP ::::: up
# the ----> DET ::::: the
#
#       ----> SPACE :::::
#
# hallway ----> NOUN ::::: hallway
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# door ----> NOUN ::::: door
# open ----> ADJ ::::: open
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# breathless ----> ADJ ::::: breathless
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# matter ----> NOUN ::::: matter
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# worried ----> ADJ ::::: worried
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# Ferris ----> PROPN ::::: Ferris
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# snaps ----> NOUN ::::: snap
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# ? ----> PUNCT ::::: ?
# For ----> ADP ::::: for
# Christ ----> PROPN ::::: Christ
# 's ----> PART ::::: 's
# sake ----> NOUN ::::: sake
# ! ----> PUNCT ::::: !
#
#                 ----> SPACE :::::
#
# Look ----> VERB ::::: look
# at ----> ADP ::::: at
# him ----> PRON ::::: he
# ! ----> PUNCT ::::: !
#
#
#    ----> SPACE :::::
#
#
# 2 ----> NUM ::::: 2
#   ----> SPACE :::::
# CLOSE ----> ADJ ::::: close
# - ----> PUNCT ::::: -
# UP ----> PROPN ::::: UP
# . ----> PUNCT ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#                                               ----> SPACE :::::
# 2 ----> NUM ::::: 2
#
#
#       ----> SPACE :::::
#
#
# An ----> DET ::::: an
# eighteen ----> NUM ::::: eighteen
# year ----> NOUN ::::: year
# - ----> PUNCT ::::: -
# old ----> ADJ ::::: old
# boy ----> NOUN ::::: boy
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# staring ----> VERB ::::: stare
# lifelessly ----> ADV ::::: lifelessly
# at ----> ADP ::::: at
# CAMERA ----> PROPN ::::: CAMERA
# . ----> PUNCT ::::: .
#
#       ----> SPACE :::::
#
# His ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# 's ----> PART ::::: 's
# open ----> ADJ ::::: open
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# are ----> AUX ::::: be
# bugged ----> VERB ::::: bug
# - ----> PUNCT ::::: -
# out ----> NOUN ::::: out
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# tongue ----> NOUN ::::: tongue
# is ----> AUX ::::: be
# fat ----> ADJ ::::: fat
#
#       ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# dry ----> ADJ ::::: dry
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# laying ----> VERB ::::: lay
# in ----> ADP ::::: in
# bed ----> NOUN ::::: bed
# , ----> PUNCT ::::: ,
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# side ----> NOUN ::::: side
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 3 ----> NUM ::::: 3
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# BOY ----> NOUN ::::: boy
# 'S ----> PART ::::: 's
# BEDROOM ----> NOUN ::::: bedroom
#                                             ----> SPACE :::::
# 3 ----> NUM ::::: 3
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# ' ----> PUNCT ::::: '
# parents ----> NOUN ::::: parent
# , ----> PUNCT ::::: ,
# TOM ----> PROPN ::::: TOM
# and ----> CCONJ ::::: and
# JOYCE ----> PROPN ::::: JOYCE
# BUELLER ----> PROPN ::::: BUELLER
# are ----> AUX ::::: be
# standing ----> VERB ::::: stand
# at ----> ADP ::::: at
#
#       ----> SPACE :::::
#
# bedside ----> NOUN ::::: bedside
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# in ----> ADP ::::: in
# their ----> PRON ::::: their
# late ----> ADJ ::::: late
# forties ----> NOUN ::::: forty
# , ----> PUNCT ::::: ,
# early ----> ADJ ::::: early
# fifties ----> NOUN ::::: fifty
# . ----> PUNCT ::::: .
#
#       ----> SPACE :::::
#
# Handsome ----> PROPN ::::: Handsome
# , ----> PUNCT ::::: ,
# upper ----> ADJ ::::: upper
# - ----> PUNCT ::::: -
# middle ----> ADJ ::::: middle
# class ----> NOUN ::::: class
# parents ----> NOUN ::::: parent
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# both ----> PRON ::::: both
# dressed ----> VERB ::::: dress
#
#       ----> SPACE :::::
#
# for ----> ADP ::::: for
# work ----> NOUN ::::: work
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Ferris ----> PROPN ::::: Ferris
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# He ----> PRON ::::: he
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# have ----> VERB ::::: have
# a ----> DET ::::: a
# fever ----> NOUN ::::: fever
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# he ----> PRON ::::: he
# says ----> VERB ::::: say
#
#                 ----> SPACE :::::
#
# his ----> PRON ::::: his
# stomach ----> NOUN ::::: stomach
# hurts ----> VERB ::::: hurt
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# seeing ----> VERB ::::: see
# spots ----> NOUN ::::: spot
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 4 ----> NUM ::::: 4
#   ----> SPACE :::::
# CLOSE ----> ADJ ::::: close
# - ----> PUNCT ::::: -
# UP ----> PROPN ::::: UP
# . ----> PUNCT ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#                                               ----> SPACE :::::
# 4 ----> NUM ::::: 4
#
#
#       ----> SPACE :::::
#
#
# His ----> PRON ::::: his
# lifeless ----> ADJ ::::: lifeless
# eyes ----> NOUN ::::: eye
# blink ----> VERB ::::: blink
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 5 ----> NUM ::::: 5
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# BEDROOM ----> NOUN ::::: bedroom
# . ----> PUNCT ::::: .
# PARENTS ----> NOUN ::::: parent
#                                          ----> SPACE :::::
# 5 ----> NUM ::::: 5
#
#
#       ----> SPACE :::::
#
#
# Tom ----> PROPN ::::: Tom
# bends ----> VERB ::::: bend
# down ----> ADP ::::: down
# and ----> CCONJ ::::: and
# touches ----> VERB ::::: touch
# Ferris ----> PROPN ::::: Ferris
# ' ----> PART ::::: '
# forehead ----> NOUN ::::: forehead
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# matter ----> NOUN ::::: matter
# , ----> PUNCT ::::: ,
# Ferris ----> PROPN ::::: Ferris
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# Feel ----> VERB ::::: feel
# his ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# cold ----> ADJ ::::: cold
# and ----> CCONJ ::::: and
# clammy ----> ADJ ::::: clammy
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# Tom ----> PROPN ::::: Tom
# takes ----> VERB ::::: take
# one ----> NUM ::::: one
# of ----> ADP ::::: of
# Ferris ----> PROPN ::::: Ferris
# ' ----> PART ::::: '
# hands ----> NOUN ::::: hand
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# discreetly ----> ADV ::::: discreetly
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Should ----> AUX ::::: should
# you ----> PRON ::::: you
# call ----> VERB ::::: call
# the ----> DET ::::: the
# doctor ----> NOUN ::::: doctor
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# whispers ----> VERB ::::: whisper
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# He ----> PRON ::::: he
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# want ----> VERB ::::: want
# me ----> PRON ::::: I
# to ----> PART ::::: to
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Why ----> SCONJ ::::: why
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# want ----> VERB ::::: want
# Mom ----> PROPN ::::: Mom
# to ----> PART ::::: to
# call ----> VERB ::::: call
#
#                 ----> SPACE :::::
#
# the ----> DET ::::: the
# doctor ----> NOUN ::::: doctor
# ? ----> PUNCT ::::: ?
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# exhales ----> VERB ::::: exhale
# loudly ----> ADV ::::: loudly
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# tries ----> VERB ::::: try
# to ----> PART ::::: to
# speak ----> VERB ::::: speak
# but ----> CCONJ ::::: but
# all ----> PRON ::::: all
# he ----> PRON ::::: he
# can ----> AUX ::::: can
#
#       ----> SPACE :::::
#
# manage ----> VERB ::::: manage
# is ----> AUX ::::: be
# a ----> DET ::::: a
# choked ----> ADJ ::::: choked
# gasp ----> NOUN ::::: gasp
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# tries ----> VERB ::::: try
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# raspy ----> ADJ ::::: raspy
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# make ----> VERB ::::: make
# a ----> DET ::::: a
# fuss ----> NOUN ::::: fuss
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# fine ----> ADJ ::::: fine
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# get ----> VERB ::::: get
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# get ----> VERB ::::: get
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# Joyce ----> PROPN ::::: Joyce
# gently ----> ADV ::::: gently
# pushes ----> VERB ::::: push
# him ----> PRON ::::: he
# back ----> ADV ::::: back
# down ----> ADV ::::: down
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# a ----> DET ::::: a
# test ----> NOUN ::::: test
# today ----> NOUN ::::: today
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# to ----> PART ::::: to
# take ----> VERB ::::: take
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# to ----> PART ::::: to
# get ----> VERB ::::: get
# into ----> ADP ::::: into
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# college ----> NOUN ::::: college
#
#                 ----> SPACE :::::
#
# so ----> SCONJ ::::: so
# I ----> PRON ::::: I
# can ----> AUX ::::: can
# have ----> VERB ::::: have
# a ----> DET ::::: a
# fruitful ----> ADJ ::::: fruitful
# life ----> NOUN ::::: life
# ... ----> PUNCT ::::: ...
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# going ----> VERB ::::: go
# to ----> ADP ::::: to
# school ----> NOUN ::::: school
# like ----> ADP ::::: like
#
#                 ----> SPACE :::::
#
# this ----> PRON ::::: this
# . ----> PUNCT ::::: .
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# to ----> ADP ::::: to
# Tom ----> PROPN ::::: Tom
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Maybe ----> ADV ::::: maybe
# I ----> PRON ::::: I
# should ----> AUX ::::: should
# call ----> VERB ::::: call
# the ----> DET ::::: the
# office ----> NOUN ::::: office
# and ----> CCONJ ::::: and
#
#                 ----> SPACE :::::
#
# tell ----> VERB ::::: tell
# them ----> PRON ::::: they
# I ----> PRON ::::: I
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# in ----> ADP ::::: in
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# , ----> PUNCT ::::: ,
# Mom ----> PROPN ::::: Mom
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# feel ----> VERB ::::: feel
# perfectly ----> ADV ::::: perfectly
# ... ----> PUNCT ::::: ...
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# God ----> PROPN ::::: God
# ! ----> PUNCT ::::: !
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# gripped ----> VERB ::::: grip
# by ----> ADP ::::: by
# a ----> DET ::::: a
# seizure ----> NOUN ::::: seizure
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# body ----> NOUN ::::: body
# stiffens ----> VERB ::::: stiffen
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# chokes ----> VERB ::::: choke
# . ----> PUNCT ::::: .
#
#       ----> SPACE :::::
#
# His ----> PRON ::::: his
# older ----> ADJ ::::: old
# sister ----> NOUN ::::: sister
# , ----> PUNCT ::::: ,
# JEANIE ----> PROPN ::::: JEANIE
# , ----> PUNCT ::::: ,
# walks ----> VERB ::::: walk
# into ----> ADP ::::: into
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# dressed ----> VERB ::::: dress
#
#       ----> SPACE :::::
#
# for ----> ADP ::::: for
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# cute ----> ADJ ::::: cute
# and ----> CCONJ ::::: and
# stuck ----> VERB ::::: stick
# - ----> PUNCT ::::: -
# up ----> NOUN ::::: up
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# major ----> ADJ ::::: major
# pill ----> NOUN ::::: pill
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEAN ----> PROPN ::::: JEAN
#
#                 ----> SPACE :::::
#
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# fine ----> ADJ ::::: fine
# . ----> PUNCT ::::: .
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# this ----> PRON ::::: this
# ? ----> PUNCT ::::: ?
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# his ----> PRON ::::: his
# problem ----> NOUN ::::: problem
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# He ----> PRON ::::: he
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# feel ----> VERB ::::: feel
# well ----> ADV ::::: well
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEAN ----> PROPN ::::: JEAN
#
#                 ----> SPACE :::::
#
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# right ----> INTJ ::::: right
# . ----> PUNCT ::::: .
# Dry ----> VERB ::::: dry
# that ----> SCONJ ::::: that
# one ----> NUM ::::: one
# out ----> ADP ::::: out
#
#                 ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# fertilize ----> VERB ::::: fertilize
# the ----> DET ::::: the
# lawn ----> NOUN ::::: lawn
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# enough ----> ADJ ::::: enough
# , ----> PUNCT ::::: ,
# Jeanie ----> PROPN ::::: Jeanie
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# falling ----> VERB ::::: fall
# for ----> ADP ::::: for
# this ----> PRON ::::: this
# , ----> PUNCT ::::: ,
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# ? ----> PUNCT ::::: ?
#
#                 ----> SPACE :::::
#
# Tell ----> VERB ::::: tell
# me ----> PRON ::::: I
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# falling ----> VERB ::::: fall
# for ----> ADP ::::: for
# this ----> PRON ::::: this
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Is ----> AUX ::::: be
# that ----> DET ::::: that
# Jeanie ----> PROPN ::::: Jeanie
# ? ----> PUNCT ::::: ?
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# see ----> VERB ::::: see
# that ----> PRON ::::: that
#
#                 ----> SPACE :::::
#
# far ----> ADV ::::: far
# . ----> PUNCT ::::: .
# Jeanie ----> PROPN ::::: Jeanie
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# Pucker ----> PROPN ::::: Pucker
# up ----> ADP ::::: up
# and ----> CCONJ ::::: and
# squat ----> VERB ::::: squat
# , ----> PUNCT ::::: ,
# Ferris ----> PROPN ::::: Ferris
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# annoyed ----> AUX ::::: annoyed
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# Jeanie ----> PROPN ::::: Jeanie
# . ----> PUNCT ::::: .
# Get ----> VERB ::::: get
# to ----> ADP ::::: to
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# angry ----> ADJ ::::: angry
# , ----> PUNCT ::::: ,
# defeated ----> VERB ::::: defeat
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# really ----> ADV ::::: really
# letting ----> VERB ::::: let
# him ----> PRON ::::: he
# stay ----> VERB ::::: stay
# home ----> ADV ::::: home
# ? ----> PUNCT ::::: ?
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# believe ----> VERB ::::: believe
# this ----> PRON ::::: this
# . ----> PUNCT ::::: .
# If ----> SCONJ ::::: if
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# bleeding ----> VERB ::::: bleed
#
#                 ----> SPACE :::::
#
# out ----> ADP ::::: out
# my ----> PRON ::::: my
# eyes ----> NOUN ::::: eye
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# guys'd ----> PROPN ::::: guys'd
# make ----> VERB ::::: make
# me ----> PRON ::::: I
# go ----> VERB ::::: go
# to ----> ADP ::::: to
#
#                 ----> SPACE :::::
#
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# so ----> ADV ::::: so
# unfair ----> ADJ ::::: unfair
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Please ----> INTJ ::::: please
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# upset ----> ADJ ::::: upset
# with ----> ADP ::::: with
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# Jeanie ----> PROPN ::::: Jeanie
# . ----> PUNCT ::::: .
#
#                 ----> SPACE :::::
#
# Be ----> AUX ::::: be
# thankful ----> ADJ ::::: thankful
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# fit ----> ADJ ::::: fit
# and ----> CCONJ ::::: and
# have ----> VERB ::::: have
#
#                 ----> SPACE :::::
#
# your ----> PRON ::::: your
# health ----> NOUN ::::: health
# . ----> PUNCT ::::: .
# Cherish ----> VERB ::::: cherish
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# to ----> ADP ::::: to
# herself ----> PRON ::::: herself
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# wanna ----> VERB ::::: wanna
# puke ----> VERB ::::: puke
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# glares ----> VERB ::::: glare
# at ----> ADP ::::: at
# Ferris ----> PROPN ::::: Ferris
# . ----> PUNCT ::::: .
# Her ----> PRON ::::: her
# eyes ----> NOUN ::::: eye
# are ----> AUX ::::: be
# mascara ----> NOUN ::::: mascara
# and ----> CCONJ ::::: and
# vengence ----> NOUN ::::: vengence
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
#
#       ----> SPACE :::::
#
# slips ----> VERB ::::: slip
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
# Ferris ----> NOUN ::::: ferris
# ' ----> PART ::::: '
# brother ----> NOUN ::::: brother
# , ----> PUNCT ::::: ,
# TODD ----> PROPN ::::: TODD
# and ----> CCONJ ::::: and
# sister ----> NOUN ::::: sister
# , ----> PUNCT ::::: ,
#
#       ----> SPACE :::::
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
# peek ----> VERB ::::: peek
# into ----> ADP ::::: into
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# Myocardial ----> ADJ ::::: myocardial
# infarction ----> NOUN ::::: infarction
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# Get ----> VERB ::::: get
# your ----> PRON ::::: your
# stuff ----> NOUN ::::: stuff
# . ----> PUNCT ::::: .
# Daddy'll ----> AUX ::::: daddy'll
# be ----> AUX ::::: be
# right ----> ADJ ::::: right
#
#                 ----> SPACE :::::
#
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# Syphilitic ----> ADJ ::::: syphilitic
# meningitus ----> NOUN ::::: meningitus
# ? ----> PUNCT ::::: ?
# That ----> PRON ::::: that
# would ----> AUX ::::: would
# be ----> AUX ::::: be
#
#                 ----> SPACE :::::
#
# a ----> DET ::::: a
# huge ----> ADJ ::::: huge
# family ----> NOUN ::::: family
# embarrassment ----> NOUN ::::: embarrassment
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Get ----> VERB ::::: get
# downstairs ----> ADV ::::: downstairs
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# If ----> SCONJ ::::: if
# he ----> PRON ::::: he
# dies ----> VERB ::::: die
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# got ----> VERB ::::: get
# dibs ----> NOUN ::::: dibs
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# stereo ----> NOUN ::::: stereo
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# turns ----> VERB ::::: turn
# sharply ----> ADV ::::: sharply
# and ----> CCONJ ::::: and
# exits ----> VERB ::::: exit
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# worried ----> ADJ ::::: worried
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Dad ----> PROPN ::::: Dad
# ? ----> PUNCT ::::: ?
# Does ----> AUX ::::: do
# my ----> PRON ::::: my
# head ----> NOUN ::::: head
# look ----> VERB ::::: look
# alright ----> ADJ ::::: alright
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# Get ----> VERB ::::: get
# downstairs ----> ADV ::::: downstairs
# ! ----> PUNCT ::::: !
# Now ----> ADV ::::: now
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                 ----> SPACE :::::
#
# Just ----> ADV ::::: just
# answer ----> VERB ::::: answer
# me ----> PRON ::::: I
# one ----> NUM ::::: one
# question ----> NOUN ::::: question
# ! ----> PUNCT ::::: !
# Is ----> AUX ::::: be
# it ----> PRON ::::: it
#
#                 ----> SPACE :::::
#
# swelling ----> VERB ::::: swell
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
# Kim ----> PROPN ::::: Kim
# said ----> VERB ::::: say
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# going ----> VERB ::::: go
#
#                 ----> SPACE :::::
#
# to ----> PART ::::: to
# get ----> VERB ::::: get
# as ----> ADV ::::: as
# big ----> ADJ ::::: big
# as ----> ADP ::::: as
# ... ----> PUNCT ::::: ...
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
# ( ----> PUNCT ::::: (
# OC ----> PROPN ::::: OC
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# A ----> DET ::::: a
# WATERMELON ----> NOUN ::::: watermelon
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# TODD ----> PROPN ::::: TODD
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# yells ----> VERB ::::: yell
# out ----> ADP ::::: out
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Shut ----> PROPN ::::: Shut
# - ----> PUNCT ::::: -
# up ----> NOUN ::::: up
# ! ----> PUNCT ::::: !
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# Get ----> VERB ::::: get
# downstairs ----> ADV ::::: downstairs
# ! ----> PUNCT ::::: !
# NOW ----> ADV ::::: now
# ! ----> PUNCT ::::: !
#
#
#       ----> SPACE :::::
#
#
# Todd ----> PROPN ::::: Todd
# backs ----> VERB ::::: back
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# just ----> ADV ::::: just
# sleep ----> VERB ::::: sleep
# . ----> PUNCT ::::: .
#
#                 ----> SPACE :::::
#
# Maybe ----> ADV ::::: maybe
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# have ----> VERB ::::: have
# an ----> DET ::::: an
# aspirin ----> NOUN ::::: aspirin
# around ----> ADP ::::: around
#
#                 ----> SPACE :::::
#
# noon ----> NOUN ::::: noon
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# to ----> ADP ::::: to
# Ferris ----> PROPN ::::: Ferris
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# showing ----> VERB ::::: show
# houses ----> NOUN ::::: house
# to ----> ADP ::::: to
# the ----> DET ::::: the
# family ----> NOUN ::::: family
#
#                 ----> SPACE :::::
#
# from ----> ADP ::::: from
# California ----> PROPN ::::: California
# today ----> NOUN ::::: today
# but ----> CCONJ ::::: but
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# in ----> ADP ::::: in
#
#                 ----> SPACE :::::
#
# the ----> DET ::::: the
# area ----> NOUN ::::: area
# . ----> PUNCT ::::: .
# My ----> PRON ::::: my
# office'll ----> NOUN ::::: office'll
# know ----> VERB ::::: know
# where ----> SCONJ ::::: where
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# need ----> VERB ::::: need
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# check ----> VERB ::::: check
# it ----> PRON ::::: it
# with ----> ADP ::::: with
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# too ----> ADV ::::: too
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# nice ----> ADJ ::::: nice
# to ----> PART ::::: to
# know ----> VERB ::::: know
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# such ----> ADJ ::::: such
#
#                 ----> SPACE :::::
#
# loving ----> NOUN ::::: loving
# , ----> PUNCT ::::: ,
# caring ----> VERB ::::: care
# parents ----> NOUN ::::: parent
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
#
#                 ----> SPACE :::::
#
# both ----> CCONJ ::::: both
# very ----> ADV ::::: very
# special ----> ADJ ::::: special
# people ----> NOUN ::::: people
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 6 ----> NUM ::::: 6
#   ----> SPACE :::::
# CU ----> PROPN ::::: CU
# . ----> PROPN ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#                                                     ----> SPACE :::::
# 6 ----> NUM ::::: 6
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# acknowledges ----> VERB ::::: acknowledge
# Tom ----> PROPN ::::: Tom
# with ----> ADP ::::: with
# a ----> DET ::::: a
# pathetic ----> ADJ ::::: pathetic
# flutter ----> NOUN ::::: flutter
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# eyelids ----> NOUN ::::: eyelid
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 7 ----> NUM ::::: 7
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# BEDROOM ----> NOUN ::::: bedroom
# . ----> PUNCT ::::: .
# JOYCE ----> PROPN ::::: JOYCE
#                                            ----> SPACE :::::
# 7 ----> NUM ::::: 7
#
#
#       ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# strokes ----> VERB ::::: stroke
# Ferris ----> PROPN ::::: Ferris
# ' ----> PART ::::: '
# hair ----> NOUN ::::: hair
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# you ----> PRON ::::: you
# feel ----> VERB ::::: feel
# better ----> ADJ ::::: well
# , ----> PUNCT ::::: ,
# pumpkin ----> NOUN ::::: pumpkin
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# She ----> PRON ::::: she
# leans ----> VERB ::::: lean
# down ----> ADV ::::: down
# and ----> CCONJ ::::: and
# kisses ----> VERB ::::: kiss
# his ----> PRON ::::: his
# forehead ----> NOUN ::::: forehead
# . ----> PUNCT ::::: .
# Tom ----> PROPN ::::: Tom
# pats ----> VERB ::::: pat
# his ----> PRON ::::: his
#
#       ----> SPACE :::::
#
# shoulder ----> NOUN ::::: shoulder
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Get ----> VERB ::::: get
# some ----> DET ::::: some
# rest ----> NOUN ::::: rest
# . ----> PUNCT ::::: .
#
#
#    ----> SPACE :::::
#
#
# 8 ----> NUM ::::: 8
#   ----> SPACE :::::
# CU ----> PROPN ::::: CU
# . ----> PROPN ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#                                                     ----> SPACE :::::
# 8 ----> NUM ::::: 8
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# lets ----> VERB ::::: let
# out ----> ADP ::::: out
# a ----> DET ::::: a
# wheeze ----> NOUN ::::: wheeze
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# glassy ----> ADJ ::::: glassy
# eyes ----> NOUN ::::: eye
# follow ----> VERB ::::: follow
# his ----> PRON ::::: his
# parents ----> NOUN ::::: parent
#
#       ----> SPACE :::::
#
# to ----> ADP ::::: to
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
# ( ----> PUNCT ::::: (
# OC ----> PROPN ::::: OC
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# We ----> PRON ::::: we
# love ----> VERB ::::: love
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# sweetie ----> NOUN ::::: sweetie
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
# ( ----> PUNCT ::::: (
# OC ----> PROPN ::::: OC
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Call ----> VERB ::::: call
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# need ----> VERB ::::: need
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
# ...
#
# ( ----> PUNCT ::::: (
# to ----> ADP ::::: to
# Todd ----> PROPN ::::: Todd
# and ----> CCONJ ::::: and
# Kimberly ----> PROPN ::::: Kimberly
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Hi ----> PROPN ::::: Hi
# , ----> PUNCT ::::: ,
# guys ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# KIMBERLY ----> PROPN ::::: KIMBERLY
#
#                 ----> SPACE :::::
#
# Is ----> AUX ::::: be
# my ----> PRON ::::: my
# head ----> NOUN ::::: head
# swelling ----> VERB ::::: swell
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# 203 ----> NUM ::::: 203
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# HOUSE ----> PROPN ::::: HOUSE
# . ----> PUNCT ::::: .
# FOYER ----> PROPN ::::: FOYER
#                                            ----> SPACE :::::
# 203 ----> NUM ::::: 203
#
#
#       ----> SPACE :::::
#
#
# The ----> DET ::::: the
# foyer ----> NOUN ::::: foyer
# is ----> AUX ::::: be
# jammed ----> ADJ ::::: jammed
# with ----> ADP ::::: with
# floral ----> ADJ ::::: floral
# arrangements ----> NOUN ::::: arrangement
# , ----> PUNCT ::::: ,
# plants ----> NOUN ::::: plant
# and ----> CCONJ ::::: and
#
#       ----> SPACE :::::
#
# gifts ----> NOUN ::::: gift
# . ----> PUNCT ::::: .
# Ferris ----> PROPN ::::: Ferris
# and ----> CCONJ ::::: and
# Jeanie ----> PROPN ::::: Jeanie
# step ----> VERB ::::: step
# gingerly ----> ADV ::::: gingerly
# through ----> ADP ::::: through
# the ----> DET ::::: the
# flowers ----> NOUN ::::: flower
#
#       ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# head ----> VERB ::::: head
# upstairs ----> ADV ::::: upstairs
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sorry ----> ADJ ::::: sorry
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# been ----> AUX ::::: be
# riding ----> VERB ::::: ride
# your ----> PRON ::::: your
#
#                 ----> SPACE :::::
#
# buns ----> NOUN ::::: bun
# for ----> ADP ::::: for
# so ----> ADV ::::: so
# long ----> ADV ::::: long
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# completely ----> ADV ::::: completely
# cool ----> ADJ ::::: cool
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
# ( ----> PUNCT ::::: (
# OC ----> PROPN ::::: OC
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Ferris ----> PROPN ::::: Ferris
# ! ----> PUNCT ::::: !
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# continues ----> VERB ::::: continue
# up ----> ADP ::::: up
# the ----> DET ::::: the
# stairs ----> NOUN ::::: stair
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# affects ----> VERB ::::: affect
# a ----> DET ::::: a
# sickly ----> ADJ ::::: sickly
# voice ----> NOUN ::::: voice
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Upstairs ----> PROPN ::::: Upstairs
# , ----> PUNCT ::::: ,
# Mom ----> PROPN ::::: Mom
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# 204 ----> NUM ::::: 204
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# SECOND ----> PROPN ::::: SECOND
# FLOOR ----> NOUN ::::: floor
# LANDING ----> PROPN ::::: LANDING
#                                    ----> SPACE :::::
# 204 ----> NUM ::::: 204
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# and ----> CCONJ ::::: and
# Jeanie ----> PROPN ::::: Jeanie
# stop ----> VERB ::::: stop
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# know ----> VERB ::::: know
# a ----> DET ::::: a
# guy ----> NOUN ::::: guy
# named ----> VERB ::::: name
# Garth ----> PROPN ::::: Garth
#
#                 ----> SPACE :::::
#
# Volbeck ----> PROPN ::::: Volbeck
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Vaguely ----> ADV ::::: vaguely
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JEANIE ----> PROPN ::::: JEANIE
#
#                 ----> SPACE :::::
#
# Is ----> AUX ::::: be
# he ----> PRON ::::: he
# cool ----> ADJ ::::: cool
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# cool ----> ADJ ::::: cool
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# stay ----> VERB ::::: stay
# away ----> ADV ::::: away
# from ----> ADP ::::: from
# his ----> PRON ::::: his
#
#                 ----> SPACE :::::
#
# brother ----> NOUN ::::: brother
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# Ferris ----> PROPN ::::: Ferris
# walks ----> VERB ::::: walk
# into ----> ADP ::::: into
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# , ----> PUNCT ::::: ,
# brushes ----> VERB ::::: brush
# the ----> DET ::::: the
# crumbs ----> NOUN ::::: crumb
# off ----> ADP ::::: off
# his ----> PRON ::::: his
# hands ----> NOUN ::::: hand
#
#       ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# peels ----> VERB ::::: peel
# off ----> ADP ::::: off
# his ----> PRON ::::: his
# shirt ----> NOUN ::::: shirt
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# climbs ----> VERB ::::: climb
# into ----> ADP ::::: into
# bed ----> NOUN ::::: bed
# . ----> PUNCT ::::: .
# No ----> ADV ::::: no
# sooner ----> ADV ::::: soon
# are ----> AUX ::::: be
#
#       ----> SPACE :::::
#
# the ----> DET ::::: the
# covers ----> NOUN ::::: cover
# over ----> ADP ::::: over
# him ----> PRON ::::: he
# than ----> SCONJ ::::: than
# the ----> DET ::::: the
# bedroom ----> NOUN ::::: bedroom
# door ----> NOUN ::::: door
# opens ----> VERB ::::: open
# and ----> CCONJ ::::: and
# Joyce ----> PROPN ::::: Joyce
#
#       ----> SPACE :::::
#
# and ----> CCONJ ::::: and
# Tom ----> PROPN ::::: Tom
# walk ----> VERB ::::: walk
# in ----> ADV ::::: in
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# walk ----> VERB ::::: walk
# over ----> ADV ::::: over
# to ----> ADP ::::: to
# the ----> DET ::::: the
# bed ----> NOUN ::::: bed
# . ----> PUNCT ::::: .
# Joyce ----> PROPN ::::: Joyce
# sits ----> VERB ::::: sit
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# Honey ----> PROPN ::::: Honey
# ? ----> PUNCT ::::: ?
#
#
#       ----> SPACE :::::
#
#
# CU ----> PROPN ::::: CU
# . ----> PUNCT ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#
#
#       ----> SPACE :::::
#
#
# The ----> DET ::::: the
# same ----> ADJ ::::: same
# deathly ----> ADJ ::::: deathly
# face ----> NOUN ::::: face
# he ----> PRON ::::: he
# had ----> VERB ::::: have
# in ----> ADP ::::: in
# the ----> DET ::::: the
# morning ----> NOUN ::::: morning
# . ----> PUNCT ::::: .
# Tongue ----> NOUN ::::: tongue
# out ----> ADP ::::: out
# , ----> PUNCT ::::: ,
#
#       ----> SPACE :::::
#
# eyes ----> NOUN ::::: eye
# bulging ----> VERB ::::: bulge
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
# ( ----> PUNCT ::::: (
# OC ----> PROPN ::::: OC
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Ferris ----> PROPN ::::: Ferris
# ? ----> PUNCT ::::: ?
# How ----> SCONJ ::::: how
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# feel ----> VERB ::::: feel
# ? ----> PUNCT ::::: ?
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# pulls ----> VERB ::::: pull
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# tongue ----> NOUN ::::: tongue
# to ----> PART ::::: to
# speak ----> VERB ::::: speak
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# deathly ----> ADV ::::: deathly
# gasp ----> ADJ ::::: gasp
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# 150 ----> NUM ::::: 150
# % ----> NOUN ::::: %
# better ----> ADJ ::::: well
# , ----> PUNCT ::::: ,
# thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# 205 ----> NUM ::::: 205
#   ----> SPACE :::::
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
# BEDROOM ----> PROPN ::::: BEDROOM
#                                                 ----> SPACE :::::
# 205 ----> NUM ::::: 205
#
#
#       ----> SPACE :::::
#
#
# Tom ----> PROPN ::::: Tom
# and ----> CCONJ ::::: and
# Joyce ----> PROPN ::::: Joyce
# hover ----> VERB ::::: hover
# over ----> ADP ::::: over
# him ----> PRON ::::: he
# with ----> ADP ::::: with
# deep ----> ADJ ::::: deep
# concern ----> NOUN ::::: concern
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# much ----> ADV ::::: much
# better ----> ADJ ::::: well
# , ----> PUNCT ::::: ,
# really ----> ADV ::::: really
# . ----> PUNCT ::::: .
# Please ----> INTJ ::::: please
# , ----> PUNCT ::::: ,
#
#                 ----> SPACE :::::
#
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# make ----> VERB ::::: make
# me ----> PRON ::::: I
# stay ----> VERB ::::: stay
# home ----> ADV ::::: home
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
#
#                 ----> SPACE :::::
#
# want ----> VERB ::::: want
# to ----> PART ::::: to
# go ----> VERB ::::: go
# to ----> ADP ::::: to
# school ----> NOUN ::::: school
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# graduating ----> VERB ::::: graduate
#
#                 ----> SPACE :::::
#
# in ----> ADP ::::: in
# June ----> PROPN ::::: June
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# ... ----> PUNCT ::::: ...
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# Ferris ----> PROPN ::::: Ferris
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# sick ----> ADJ ::::: sick
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# no ----> DET ::::: no
# point ----> NOUN ::::: point
#
#                 ----> SPACE :::::
#
# pushing ----> VERB ::::: push
# yourself ----> PRON ::::: yourself
# and ----> CCONJ ::::: and
# making ----> VERB ::::: make
# it ----> PRON ::::: it
# worse ----> ADJ ::::: bad
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Maybe ----> ADV ::::: maybe
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# right ----> ADJ ::::: right
# , ----> PUNCT ::::: ,
# Dad ----> PROPN ::::: Dad
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# TOM ----> PROPN ::::: TOM
#
#                 ----> SPACE :::::
#
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# right ----> ADJ ::::: right
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# Joyce ----> PROPN ::::: Joyce
# leans ----> VERB ::::: lean
# over ----> ADV ::::: over
# and ----> CCONJ ::::: and
# kisses ----> VERB ::::: kiss
# him ----> PRON ::::: he
# forehead ----> NOUN ::::: forehead
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# JOYCE ----> PROPN ::::: JOYCE
#
#                 ----> SPACE :::::
#
# How ----> SCONJ ::::: how
# did ----> AUX ::::: do
# you ----> PRON ::::: you
# get ----> VERB ::::: get
# so ----> ADV ::::: so
# sweet ----> ADJ ::::: sweet
# ? ----> PUNCT ::::: ?
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# Years ----> NOUN ::::: year
# of ----> ADP ::::: of
# practice ----> NOUN ::::: practice
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# Tom ----> PROPN ::::: Tom
# pats ----> VERB ::::: pat
# Ferris ----> PROPN ::::: Ferris
# on ----> ADP ::::: on
# the ----> DET ::::: the
# rump ----> NOUN ::::: rump
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# and ----> CCONJ ::::: and
# Joyce ----> PROPN ::::: Joyce
# exit ----> NOUN ::::: exit
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# CU ----> PROPN ::::: CU
# . ----> PUNCT ::::: .
# FERRIS ----> PROPN ::::: FERRIS
#
#
#       ----> SPACE :::::
#
#
# The ----> DET ::::: the
# hideous ----> ADJ ::::: hideous
# face ----> NOUN ::::: face
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# beat ----> NOUN ::::: beat
# and ----> CCONJ ::::: and
# we ----> PRON ::::: we
# HEAR ----> VERB ::::: hear
# THE ----> DET ::::: the
# BEDROOM ----> NOUN ::::: bedroom
# DOOR ----> PROPN ::::: DOOR
# CLOSE ----> PROPN ::::: CLOSE
# . ----> PUNCT ::::: .
#
#       ----> SPACE :::::
#
# Ferris ----> PROPN ::::: Ferris
# looks ----> VERB ::::: look
# at ----> ADP ::::: at
# CAMERA ----> PROPN ::::: CAMERA
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                            ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# happy ----> ADJ ::::: happy
# sigh ----> NOUN ::::: sigh
# ) ----> PUNCT ::::: )
#
#                 ----> SPACE :::::
#
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# life ----> NOUN ::::: life
# is ----> AUX ::::: be
# a ----> DET ::::: a
# carousel ----> NOUN ::::: carousel
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
#
#                 ----> SPACE :::::
#
# great ----> ADJ ::::: great
# big ----> ADJ ::::: big
# crazy ----> ADJ ::::: crazy
# ball ----> NOUN ::::: ball
# of ----> ADP ::::: of
# pure ----> ADJ ::::: pure
#
#                 ----> SPACE :::::
#
# living ----> NOUN ::::: living
# , ----> PUNCT ::::: ,
# breathing ----> VERB ::::: breathe
# joy ----> NOUN ::::: joy
# and ----> CCONJ ::::: and
# delight ----> NOUN ::::: delight
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# rolls ----> VERB ::::: roll
# over ----> ADP ::::: over
# on ----> ADP ::::: on
# his ----> PRON ::::: his
# back ----> NOUN ::::: back
# and ----> CCONJ ::::: and
# puts ----> VERB ::::: put
# his ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# behind ----> ADP ::::: behind
# his ----> PRON ::::: his
#
#       ----> SPACE :::::
#
# head ----> NOUN ::::: head
# . ----> PUNCT ::::: .
#
#
#                                ----> SPACE :::::
#
#
# FERRIS ----> PROPN ::::: FERRIS
#
#                 ----> SPACE :::::
#
# You ----> PRON ::::: you
# got ----> VERB ::::: got
# ta ----> PART ::::: to
# get ----> VERB ::::: get
# one ----> NUM ::::: one
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# smiles ----> VERB ::::: smile
# . ----> PUNCT ::::: .
#
#
#       ----> SPACE :::::
#
#
# MUSIC ----> NOUN ::::: music
# UP ----> ADP ::::: up
# BIG ----> ADJ ::::: big
#
#
#       ----> SPACE :::::
#
#
# END ----> PROPN ::::: END
# TITLES ----> PROPN ::::: TITLES
#
#
#                                ----> SPACE :::::
#
#
# THE ----> DET ::::: the
# END ----> PROPN ::::: END

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("DET")
# Out:
# 'determiner'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('tight', 'ferris'), ('dangerous', 'ferris'), ('annoyed', 'ferris'), ('throbbing', 'ferris'), ('selfish', 'ferris'), ('kinda', 'ferris'), ('black', 'ferris'), ('cool', 'ferris'), ('condescending', 'ferris'), ('close', 'ferris'), ('hasty', 'ferris'), ('floral', 'ferris'), ('gross', 'ferris'), ('dusty', 'ferris'), ('tweedy', 'ferris'), ('famous', 'ferris'), ('disappointed', 'ferris'), ('relaxed', 'ferris'), ('good', 'ferris'), ('lifeless', 'ferris'), ('heavy', 'ferris'), ('impending', 'ferris'), ('scenic', 'ferris'), ('other', 'ferris'), ('baffled', 'ferris'), ('worthless', 'ferris'), ('terrible', 'ferris'), ('thick', 'ferris'), ('omnious', 'ferris'), ('wet', 'ferris'), ('ninth', 'ferris'), ('overhead', 'ferris'), ('used', 'ferris'), ('american', 'ferris'), ('mammoth', 'ferris'), ('single', 'ferris'), ('glorious', 'ferris'), ('willing', 'ferris'), ('clear', 'ferris'), ('right', 'ferris'), ('passing', 'ferris'), ('honest', 'ferris'), ('mean', 'ferris'), ('tiny', 'ferris'), ('vacant', 'ferris'), ('sadistic', 'ferris'), ('tough', 'ferris'), ('risky', 'ferris'), ('upset', 'ferris'), ('shitless', 'ferris'), ('specific', 'ferris'), ('modest', 'ferris'), ('small', 'ferris'), ('bad', 'ferris'), ('outer', 'ferris'), ('myocardial', 'ferris'), ('angry', 'ferris'), ('skinny', 'ferris'), ('syphilitic', 'ferris'), ('old', 'ferris'), ('normal', 'ferris'), ('okay', 'ferris'), ('bright', 'ferris'), ('happy', 'ferris'), ('homely', 'ferris'), ('much', 'ferris'), ('Less', 'ferris'), ('dear', 'ferris'), ('impressed', 'ferris'), ('guilty', 'ferris'), ('huge', 'ferris'), ('fetid', 'ferris'), ('new', 'ferris'), ('like', 'ferris'), ('rotund', 'ferris'), ('charming', 'ferris'), ('sure', 'ferris'), ('ready', 'ferris'), ('gasp', 'ferris'), ('colorless', 'ferris'), ('pink', 'ferris'), ('exciting', 'ferris'), ('substantial', 'ferris'), ('beefoid', 'ferris'), ('crazy', 'ferris'), ('dreary', 'ferris'), ('common', 'ferris'), ('fair', 'ferris'), ('fun', 'ferris'), ('front', 'ferris'), ('loud', 'ferris'), ('funny', 'ferris'), ('suburban', 'ferris'), ('same', 'ferris'), ('unfair', 'ferris'), ('awful', 'ferris'), ('aged', 'ferris'), ('weird', 'ferris'), ('additional', 'ferris'), ('silver', 'ferris'), ('ignorant', 'ferris'), ('frightening', 'ferris'), ('pebbled', 'ferris'), ('ashen', 'ferris'), ('imaginary', 'ferris'), ('tense', 'ferris'), ('fixable', 'ferris'), ('alright', 'ferris'), ('major', 'ferris'), ('stiff', 'ferris'), ('perfect', 'ferris'), ('tall', 'ferris'), ('speedy', 'ferris'), ('clean', 'ferris'), ('friendly', 'ferris'), ('likely', 'ferris'), ('obscene', 'ferris'), ('steamy', 'ferris'), ('slavic', 'ferris'), ('cold', 'ferris'), ('sad', 'ferris'), ('placcid', 'ferris'), ('hearty', 'ferris'), ('second', 'ferris'), ('mature', 'ferris'), ('brief', 'ferris'), ('pathetic', 'ferris'), ('aware', 'ferris'), ('enriching', 'ferris'), ('open', 'ferris'), ('mint', 'ferris'), ('mindless', 'ferris'), ('cavalier', 'ferris'), ('strange', 'ferris'), ('dramatic', 'ferris'), ('curious', 'ferris'), ('considerate', 'ferris'), ('low', 'ferris'), ('compatible', 'ferris'), ('fabulous', 'ferris'), ('dark', 'ferris'), ('straight', 'ferris'), ('social', 'ferris'), ('distinctive', 'ferris'), ('giant', 'ferris'), ('litttle', 'ferris'), ('thankful', 'ferris'), ('typewritten', 'ferris'), ('chipper', 'ferris'), ('proud', 'ferris'), ('graphic', 'ferris'), ('rich', 'ferris'), ('polluted', 'ferris'), ('reprehensible', 'ferris'), ('married', 'ferris'), ('gritty', 'ferris'), ('enough', 'ferris'), ('interesting', 'ferris'), ('established', 'ferris'), ('only', 'ferris'), ('myopic', 'ferris'), ('critical', 'ferris'), ('pure', 'ferris'), ('childish', 'ferris'), ('dirty', 'ferris'), ('excited', 'ferris'), ('scorching', 'ferris'), ('slack', 'ferris'), ('light', 'ferris'), ('digestive', 'ferris'), ('catholic', 'ferris'), ('rowdy', 'ferris'), ('pretty', 'ferris'), ('phoney', 'ferris'), ('impish', 'ferris'), ('pissed', 'ferris'), ('scary', 'ferris'), ('crusty', 'ferris'), ('lean', 'ferris'), ('bull ...

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)
# Out:
#         word nodeType    unit
# 0      black      ADJ  ferris
# 1     silent      ADJ  ferris
# 2      ready      ADJ  ferris
# 3      aural      ADJ  ferris
# 4        old      ADJ  ferris
# ...      ...      ...     ...
# 1139   great      ADJ  ferris
# 1140     big      ADJ  ferris
# 1141   crazy      ADJ  ferris
# 1142    pure      ADJ  ferris
# 1143     big      ADJ  ferris
#
# [1144 rows x 3 columns]

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a dataframe as a TSV file.

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData-2.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a NEW dataframe as a NEW TSV file.

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.
