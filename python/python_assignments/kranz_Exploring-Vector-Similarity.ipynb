# %% [markdown]
# # Words by Numbers: Exploring Vector Similarity
# This notebook accompanies our readings on AI, to help explore words of interest as "vector embeddings". As we are learning from our readings, in the making of a large language model, they consist of calculations about meaningful units of language (words / tokenized particles) and they calculate relationships based on mathematical vectors.
#
# In this digital humanities orientation to language models and word embeddings, we'll reach for the number values ("vector word embedding values") that language models apply to word-tokens when they read and generate them.
#
# *My first version of this notebook is [this Python file](https://github.com/newtfire/textAnalysis-Hub/blob/main/Class-Examples/Python/readFileCollections-examples/readingFileCollection.py) also stored in our textAnalysis-Hub Python collection.
#
# ## Pay attention to an interesting word: A little lab test of LLMs
# We'll just do this as a test case based on some text file outputs from any generative AI. (You can also adapt this script to explore your own text corpora for your projects.) For our demonstration, we'll run a little experiment on generative AI chatbots (ChatGPT, Claude, Gemini, etc). We can give a couple of these bots the same prompt, and save the outputs in a directory. Then we'll run this notebook over them.
#
# When you review outputs to your prompts, do you see a **word or idea** that's sometimes repeated or that seems an interesting basis for comparison across the files? Take your cue from this: Choose a word of interest that you think is worth "paying attention to" as a basis for comparing the text outputs of the AI (or the texts in your collection). In this notebook, we'll use it as a basis for comparing all the files: **how often do they use a similar word**, that is, a "similar" word based on a language model's calculations of similarity?
#
# For our experiment, we'll work with spaCy's freely available large language model, to access its vector database on words and return calculations. Python can "crunch the numbers" to show us which prompts are using words that are mapped to a nearby "vector space" in spaCy's language model. This Python script can help show us how our texts compare to each other based on how often they draw from words that share similar number values.
#
# For this experiment we'll be accessing the **cosine similarity** values that LLMs reach for in calculating a response to a prompt. The only difference is, we're using spaCy's embedding dictionary as our basis for exploring. (Our little experiment is simply using spaCy's vector embeddings as our similarity measuring instrument. To take this further, we could try to get "under the hood" of each LLM to access its distinctive vector database.)
#
# ## Installs and imports
# * spacy
# * spacy's large language model
# * os for handling filepaths

# %%
import spacy
import os

# I NEED THE SPACY DOWNLOAD FOR THE LANGUAGE MODEL HERE.
nlp = spacy.load('en_core_web_lg')
# COMMENT OUT THE spacy.load line after the first time you load your model!
# If the large one is too big, you can use the medium:
# nlp = spacy.load('en_core_web_md')
# en_core_web_md: size: 34 MB )
# en_core_web_lg (Lots of data here, size: 400 MB.) Note that the LARGEST one will have the most data and probably be the most reliable.

# %% [markdown]
# ### Identify the directory to read
# So, you have a collection of text files that you want to compare, and you've stored them in a directory(folder).
# Which directory do you want the Python script to read? Define it in relation to where you saved your Python file.

# %%
collection = 'texts'
# This is a folder saved in the same directory with this Python notebook.

# %%
# "Smoke test": Open the directory and make sure we can access the files inside. 
# Here's where we use os.
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
    # ebb: add that utf8 encoding argument to the open() function to ensure that reading works on everyone's systems
    # this all succeeds if you see the text of your files printed in the console.
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)
        lengthFile = len(readFile)
        # (Literally, we'll just count the number of characters in this.)
        print(lengthFile)

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        print(filepath)
        readTextFiles(filepath)
# Out:
# texts/breakfast.txt
# 129108
# texts/sixteen.txt
# 160864

# %% [markdown]
# ### Apply spaCy's language model
#
# * First we'll have spaCy tokenize and "read" the files, just using its default tokenizer.
# * Then we'll choose our **word of interest** that we'll use as a basis for exploring similarity.
# * We'll then create a **dictionary of highly similar values** to that word, drawn from spaCy's vector database.
#
# The similarity value is called "cosine similarity" and it varies between 0 and 1, with 1 being closest to identical.
# Try adjusting the "similarity gage" by tweaking the number in the second if statement:
#
# ```py
#             if wordOfInterest.similarity(token) > .3:
# ```
#
# How does changing this value affect the results you see?

# %%
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)

        tokens = nlp(stringFile)
        # playing with vectors here
        vectors = tokens.vector
        # Want to "see" some vector information? Uncomment the  next line:
        print(vectors)

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        readTextFiles(filepath)
# Out:
# [-4.76245359e-02  1.65148228e-01 -1.30200148e-01 -6.64106682e-02
#   7.63094574e-02 -2.28473730e-03  2.82227322e-02 -1.21189274e-01
#  -2.70061214e-02  1.62962532e+00 -1.58736631e-01  3.13014351e-02
#   7.03500435e-02 -7.40286261e-02 -1.44381449e-01 -1.31716784e-02
#  -5.05471118e-02  7.91358948e-01 -1.38889983e-01  1.25758920e-03
#   5.12803271e-02 -3.47130606e-03 -1.85405444e-02 -4.05540168e-02
#   5.12745045e-03  1.28774270e-02 -7.51902759e-02 -3.09352856e-02
#   8.77762660e-02 -7.69974962e-02 -3.15146483e-02  1.04475848e-01
#  -5.69244958e-02  8.06982890e-02  7.45510459e-02 -3.45903635e-02
#   2.38528363e-02  8.77986550e-02 -8.15537274e-02 -3.20069753e-02
#   1.21239629e-02  1.82465259e-02 -8.29399843e-03 -7.07079396e-02
#   5.02320901e-02  7.79762045e-02 -1.44033179e-01 -3.41775194e-02
#   2.57057603e-02  2.46572141e-02 -1.00684064e-02  5.07621877e-02
#   1.30882338e-02 -2.85084583e-02  1.76655333e-02  9.58173815e-03
#  -1.47783756e-02 -3.90408561e-02  3.27310339e-02 -6.26947954e-02
#  -6.78112507e-02 -5.24519645e-02 -2.50785667e-02  1.03262641e-01
#   5.51844686e-02 -1.01404503e-01 -4.82725948e-02  6.55247271e-02
#   4.23200466e-02  9.92092937e-02  5.01429252e-02  1.62646417e-02
#   1.99904844e-01 -1.26861474e-02  4.98371571e-02  4.98455688e-02
#   7.00429231e-02 -6.03655241e-02 -5.52362576e-02  1.89477250e-01
#  -2.03771447e-03  8.72273967e-02 -7.93830231e-02  1.69624332e-02
#  -1.38829264e-03 -1.59065947e-01  2.58229375e-01 -2.00037792e-01
#   1.91648811e-01  5.77897392e-02 -7.50389844e-02  7.35743390e-03
#  -4.24794629e-02 -6.59436360e-03  8.75417888e-02 -3.01560592e-02
#  -3.30216363e-02 -7.29462281e-02 -4.56912816e-02 -9.54860821e-03
#  -8.55558738e-03  3.46787423e-02 -5.37909418e-02 -3.44666727e-02
#   5.87446839e-02 -3.81495267e-01  1.01047903e-01 -4.20237035e-02
#   3.37825826e-04  2.16207523e-02  6.48458302e-02 -1.37638345e-01
#   1.08079396e-01 -8.05444494e-02  3.63462418e-02 -3.43503337e-03
#   4.78442647e-02 -4.08017635e-02 -4.51878756e-02 -1.74065661e-02
#   6.87137097e-02 -4.34237532e-02  2.31941324e-02  2.19521625e-03
#   2.89787166e-02  4.66201492e-02 -4.06126343e-02 -9.11448821e-02
#   4.01903987e-02 -1.61306243e-02 -3.31938639e-02 -5.74549884e-02
#  -5.71075827e-02  3.73991281e-02  7.97355548e-02  5.52689517e-03
#  -2.62238011e-02  5.64183900e-03 -5.91333322e-02 -1.10059939e-02
#  -1.26032305e+00  1.05772547e-01  9.25393403e-02  8.23078677e-03
#  -2.67024301e-02 -3.64992544e-02 -4.69009392e-02  5.16145490e-02
#  -4.87477630e-02 -7.90283978e-02 -3.36564332e-02  4.53648902e-02
#   4.78756204e-02  1.41147664e-02  2.71466896e-02 -5.95199801e-02
#  -1.53842345e-02 -8.13658386e-02  5.21655893e-05 -3.12730074e-02
#  -1.33321015e-02  1.29824420e-02 -8.01979601e-02 -9.84623842e-03
#  -8.58335383e-03 -8.57803226e-02  2.30859146e-02 -3.42356227e-02
#   8.92784297e-02  4.67627235e-02 -5.38335331e-02 -2.80280393e-02
#   1.36992196e-02 -8.16124827e-02 -5.34810834e-02  2.29999553e-02
#  -4.60377708e-02  2.23794896e-02 -1.92224849e-02 -3.96465845e-02
#   1.40094142e-02 -4.20161746e-02 -1.15500957e-01 -4.90429960e-02
#  -1.00384280e-02  3.74932657e-03 -3.26362550e-02 -2.30658352e-02
#   7.37826303e-02  2.73606740e-02  3.22864018e-03  1.23540480e-02
#  -7.06290156e-02 -2.12928243e-02  1.36592062e-02  1.08591743e-01
#  -4.97938357e-02 -1.09427482e-01  4.86531295e-02  1.39744192e-01
#  -6.41801059e-02 -3.14402319e-02 -4.50733788e-02 -5.14441431e-02
#   1.00189604e-01 -6.65134890e-03  3.81121822e-02 -1.05849458e-02
#   5.99269718e-02 -4.94246222e-02 -8.74441937e-02 -6.32808432e-02
#  -1.94674786e-02 -5.85184880e-02  5.99860549e-02  8.46744925e-02
#  -4.41350304e-02  2.04291232e-02 -1.36444196e-01  1.53415352e-02
#   4.19199467e-03  3.90265621e-02 -5.61110824e-02  1.70043726e-02
#   1.63670499e-02 -3.43287108e-03 -6.69644848e-02  8.28517228e-02
#  -9.65943933e-03 -2.92317551e-02 -8.79549310e-02  8.99385568e-03
#   7.55257979e-02  6.24952503e-02 -7.86261037e-02 -5.05538806e-02
#  -5.78867877e-03 -8.04156587e-02 -7.73826018e-02  9.19639468e-02
#   3.45014259e-02  3.11195161e-02  1.87936407e-02  7.54725933e-02
#   7.35660642e-02 -1.23341709e-01 -5.80314249e-02 -4.24541607e-02
#  -1.21336378e-01  1.40823111e-01  4.68669347e-02 -8.21063742e-02
#  -6.61983341e-02 -1.30444986e-03  1.91489626e-02  1.28129587e-01
#   2.73012873e-02 -6.40854165e-02 -2.50484627e-02  4.02109139e-02
#   3.47406603e-02  1.13118835e-01  1.79801211e-02  4.26233560e-02
#   6.72606677e-02 -5.45939095e-02 -4.30508219e-02  4.80527095e-02
#   1.96180090e-01  5.51205575e-02 -2.80975532e-02 -3.93756256e-02
#  -7.32667595e-02 -6.19102307e-02 -9.29699689e-02  3.61977480e-02
#   3.72206457e-02  4.15877206e-03 -4.83148819e-04  1.48482636e-01
#   1.31585583e-01 -5.23072341e-03 -1.70302633e-02 -4.51975763e-02
#  -2.37757470e-02 -5.14610782e-02  1.11093879e-01 -6.78966120e-02
#   7.42037669e-02 -2.83871070e-02 -7.85472393e-02  2.73747556e-03
#  -2.44150255e-02 -5.56269363e-02  6.82998598e-02 -3.06933578e-02
#  -2.05108467e-02 -2.51707360e-02  1.42825600e-02  4.77290824e-02]
# [-7.27622304e-03  1.36234701e-01 -1.31028861e-01 -4.32766452e-02
#   1.26037702e-01  1.02642570e-02  1.62249692e-02 -1.42199159e-01
#   2.16853190e-02  1.45665157e+00 -1.64254457e-01  1.11671146e-02
#   3.24584357e-02 -8.51001814e-02 -9.06876773e-02 -1.53107438e-02
#  -4.92707603e-02  8.55196178e-01 -1.28326252e-01 -5.34131890e-04
#   1.37556773e-02 -8.84607434e-03 -6.36534840e-02 -8.63719210e-02
#   1.06907440e-02 -4.13282588e-02 -3.21969427e-02 -6.65341988e-02
#   5.10725081e-02 -4.05462869e-02 -5.78300171e-02  8.35610479e-02
#  -4.32671905e-02  6.00982718e-02  1.12671070e-01 -7.18781650e-02
#  -2.70252377e-02  8.51398483e-02 -6.40987083e-02 -1.28941042e-02
#   4.93991934e-02  4.40370589e-02  1.77838393e-02 -4.19666953e-02
#   3.12158931e-03  7.13327061e-03 -1.02620743e-01 -5.15497336e-03
#   2.07107328e-02  8.86826310e-03 -1.92723498e-02  2.98049692e-02
#  -1.17923673e-02 -4.99679819e-02 -7.92954024e-03  3.80287245e-02
#  -5.58845997e-02 -3.71978357e-02  2.81134546e-02 -7.01021627e-02
#  -6.19986616e-02 -1.49423378e-02  4.54264460e-03  7.41728544e-02
#   5.26471995e-02 -4.23128866e-02 -2.15788539e-02  7.07160011e-02
#   4.26375121e-02  1.00459464e-01  3.37263718e-02  4.29123119e-02
#   1.20588109e-01  2.48551443e-02  7.86962882e-02  1.05276570e-01
#   2.25240272e-02 -3.13396230e-02 -4.91546541e-02  6.62759319e-02
#   2.14365078e-03  1.18510611e-01 -1.16059683e-01  5.87724485e-02
#  -5.81477070e-03 -1.15654714e-01  2.14299917e-01 -1.94763944e-01
#   1.31630793e-01  9.21257958e-02 -1.02275856e-01  3.88658531e-02
#   1.27825132e-02 -7.28531182e-02  7.58490860e-02 -2.89233066e-02
#  -3.27848680e-02 -4.08967026e-02 -4.33129855e-02  1.76931883e-03
#   1.33573674e-02  2.94818655e-02 -4.72550876e-02 -4.17795368e-02
#   5.12965880e-02 -1.86099067e-01  1.37620941e-01 -4.93819490e-02
#   6.88581076e-03  1.92406550e-02  6.53645247e-02 -1.51291043e-01
#   7.57451579e-02 -8.41786936e-02  2.07600165e-02  3.75324889e-04
#   3.70576009e-02 -5.67158908e-02 -1.13809807e-02 -2.16707923e-02
#   4.25033718e-02 -5.65715693e-02  5.44325486e-02  2.45619658e-03
#  -4.11282741e-02  6.43233284e-02 -4.69569452e-02 -1.00111090e-01
#   3.80802341e-02 -2.04077512e-02 -4.56309617e-02  1.44816274e-02
#  -7.48389661e-02  2.97310557e-02  1.14515841e-01  1.86312236e-02
#  -2.23882385e-02  3.44946533e-02 -5.34060374e-02 -2.92679295e-03
#  -1.10789192e+00  8.10862482e-02  6.52831346e-02  3.31545802e-04
#  -3.60983051e-02  1.36463139e-02 -7.91177228e-02  3.13622318e-02
#  -3.45046818e-02 -1.82014443e-02 -7.18923239e-03  8.64237994e-02
#   4.84026000e-02  2.52097901e-02  1.05899023e-02 -8.25196803e-02
#  -4.32540365e-02 -2.71210950e-02  5.61772585e-02 -6.67913556e-02
#   2.40790602e-02  1.14893960e-02 -6.31107539e-02 -3.80930826e-02
#  -4.14966308e-02 -1.35267988e-01 -2.82355398e-03 -5.78325465e-02
#   6.01007007e-02  5.49016856e-02 -2.13032775e-02  1.91854443e-02
#  -2.69118771e-02 -7.90720731e-02 -5.23115322e-02  2.98030525e-02
#   1.27304171e-03  3.75808850e-02 -3.39697376e-02 -4.62268218e-02
#   9.93758626e-03 -1.02929361e-01 -8.53479654e-02 -5.53927012e-02
#  -7.90941939e-02  1.97233930e-02 -4.14297879e-02 -7.11724022e-03
#   3.43144499e-02 -5.26550598e-03 -1.12901060e-02  3.71276541e-03
#  -9.73442718e-02  3.46431173e-02  6.31628111e-02  5.29155731e-02
#  -2.18075875e-04 -1.64334506e-01  2.36486201e-03  1.19173981e-01
#  -7.15749487e-02 -2.95107868e-02 -7.00307116e-02  2.99392864e-02
#   7.52962902e-02 -1.93373412e-02  4.13287617e-02 -2.42517702e-02
#   5.56094944e-03 -7.11782798e-02 -8.22674185e-02 -1.13142624e-01
#  -1.12290699e-02 -1.02471814e-01  8.87520015e-02  3.96491773e-02
#  -4.29646224e-02 -1.72357727e-02 -1.48022518e-01 -1.33766551e-02
#   2.80916989e-02  8.04654285e-02 -5.89736961e-02  2.14449819e-02
#  -1.97733976e-02  1.00727174e-02 -1.43027753e-02  3.81415151e-02
#   7.34814852e-02 -1.80848483e-02 -8.49510431e-02 -3.15367132e-02
#   9.81211439e-02  1.86752100e-02 -7.02531040e-02 -4.82439548e-02
#  -5.77673577e-02 -3.16059813e-02 -7.29903355e-02  4.99387942e-02
#  -2.38805562e-02  5.39921522e-02  2.23773010e-02  4.00226749e-02
#   4.56529222e-02 -8.54105577e-02 -5.82344495e-02 -9.08746645e-02
#  -1.00381747e-01  7.67227933e-02 -3.98997869e-03 -4.40992676e-02
#  -2.88434736e-02 -3.51244621e-02  1.82611197e-02  2.14289322e-01
#   6.42794743e-02 -3.64120081e-02 -1.01805488e-02  2.12726928e-02
#   1.91162191e-02  1.29223734e-01  8.25973377e-02  2.94449702e-02
#   9.20996293e-02 -5.60595132e-02 -4.87183854e-02  1.71071496e-02
#   1.83080792e-01  2.05994700e-03 -3.75288986e-02 -3.17825712e-02
#  -5.01429252e-02 -1.05735444e-01 -5.08076325e-02 -4.29081172e-03
#   4.19858210e-02  5.45172021e-02 -3.03023532e-02  1.28055513e-01
#   1.39990643e-01  2.38666404e-02 -1.80287790e-02 -5.57960011e-02
#  -4.09704028e-03 -5.16259894e-02  8.69455040e-02 -5.15380204e-02
#   1.25176907e-01 -2.62366254e-02 -6.69810222e-03  1.62952412e-02
#  -3.75250876e-02 -8.24406892e-02  2.31252871e-02 -2.08672937e-02
#   1.39660360e-02 -2.59761722e-03 -2.25634724e-02  4.60676253e-02]

# %%
def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)

        tokens = nlp(stringFile)
        # playing with vectors here
        vectors = tokens.vector
        # Want to "see" some vector information? Uncomment the  next line:
        # print(vectors)

        wordOfInterest = nlp(u'panic')

         # Now, let's open an empty dictionary! We'll fill it up with the for loop just after it.
        # The for-loop goes over each token and gets its values
        highSimilarityDict = {}
        for token in tokens:
            if(token and token.vector_norm):
                if wordOfInterest.similarity(token) > .4:
                # ^^^^ our "similarity gage" ^^^^
                    highSimilarityDict[token] = wordOfInterest.similarity(token)
                    # The line above creates the structure for each entry in my dictionary.
                        # print(token.text, "about this much similar to", wordOfInterest, ": ", wordOfInterest.similarity(token))
        print(f'This is a dictionary of words most similar to the word "{wordOfInterest.text}" in "{file}".')
        print(highSimilarityDict)
        print('\n')

        

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        readTextFiles(filepath)
# Out:
# This is a dictionary of words most similar to the word "panic" in "breakfast.txt".
# {crazy: 0.4205722212791443, brain: 0.41149720549583435, sort: 0.41327935457229614, upset: 0.4269835650920868, angry: 0.44234710931777954, stop: 0.4402228891849518, confusion: 0.5925239324569702, mistake: 0.4031905233860016, sleep: 0.5002427697181702, when: 0.43749767541885376, mess: 0.40713033080101013, utter: 0.4334380626678467, confusion: 0.5925239324569702, embarrassed: 0.40131354331970215, uncomfortable: 0.4029877781867981, ignore: 0.4248170852661133, happening: 0.40955767035484314, when: 0.43749767541885376, angry: 0.44234710931777954, temper: 0.42683684825897217, nervous: 0.5641590356826782, pain: 0.5249786972999573, pain: 0.5249786972999573, ignore: 0.4248170852661133, ignore: 0.4248170852661133, upset: 0.4269835650920868, moment: 0.44734853506088257, emotions: 0.493652880191803, hurt: 0.41069528460502625, afraid: 0.49458327889442444, afraid: 0.49458327889442444, situation: 0.47141218185424805, felt: 0.40701329708099365, agony: 0.47676199674606323, hurt: 0.41069528460502625, worried: 0.5002680420875549, Stop: 0.4402228891849518, when: 0.43749767541885376, trying: 0.4293230473995209, trying: 0.4293230473995209, asleep: 0.43356144428253174, Wake: 0.5036436319351196, when: 0.43749767541885376, Suddenly: 0.5244616866111755, feeling: 0.49194496870040894, problem: 0.439698725938797, when: 0.43749767541885376, felt: 0.40701329708099365, upset: 0.4269835650920868, mess: 0.40713033080101013, trying: 0.4293230473995209, embarrassed: 0.40131354331970215, Wake: 0.5036436319351196, Wake: 0.5036436319351196, When: 0.43749767541885376, Whenever: 0.44008639454841614, stop: 0.4402228891849518, happening: 0.40955767035484314, disgust: 0.44011929631233215, When: 0.43749767541885376, trying: 0.4293230473995209, problem: 0.439698725938797, Suddenly: 0.5244616866111755, anymore: 0.4066499173641205, hurt: 0.41069528460502625, when: 0.43749767541885376, anymore: 0.4066499173641205, when: 0.43749767541885376, bad: 0.4104759991168976, stop: 0.4402228891849518, trying: 0.4293230473995209, when: 0.43749767541885376, alarm: 0.46710968017578125, cry: 0.4494827389717102, bad: 0.4104759991168976, When: 0.43749767541885376, threatening: 0.41319841146469116, screaming: 0.47426164150238037, coughing: 0.41055890917778015, mental: 0.47315868735313416, illness: 0.5038530826568604, happening: 0.40955767035484314, embarrassed: 0.40131354331970215, suddenly: 0.5244616866111755, confusion: 0.5925239324569702, mind: 0.4265080988407135, worst: 0.4175437390804291, realize: 0.4097926616668701, suddenly: 0.5244616866111755, hurt: 0.41069528460502625, when: 0.43749767541885376, feeling: 0.49194496870040894, violent: 0.4095677435398102, dangers: 0.40470069646835327, cry: 0.4494827389717102, problems: 0.47720131278038025, problems: 0.47720131278038025, problem: 0.439698725938797, problems: 0.47720131278038025, bad: 0.4104759991168976, bad: 0.4104759991168976, crying: 0.5160260796546936, ignore: 0.4248170852661133, crying: 0.5160260796546936, when: 0.43749767541885376, When: 0.43749767541885376, trying: 0.4293230473995209, serious: 0.4416359066963196, when: 0.43749767541885376, when: 0.43749767541885376, when: 0.43749767541885376, moment: 0.44734853506088257, mind: 0.4265080988407135, when: 0.43749767541885376, attention: 0.4063165783882141, disgust: 0.44011929631233215, crazy: 0.4205722212791443, crazy: 0.4205722212791443, when: 0.43749767541885376, suddenly: 0.5244616866111755, sleep: 0.5002427697181702, verge: 0.4257688522338867, psychological: 0.46485039591789246, screaming: 0.47426164150238037, screaming: 0.47426164150238037, Silence: 0.41072094440460205, compulsive: 0.43264853954315186, when: 0.43749767541885376, when: 0.43749767541885376, when: 0.43749767541885376, feeling: 0.49194496870040894, weakness: 0.4483109414577484, when: 0.43749767541885376, felt: 0.40701329708099365, crying: 0.5160260796546936, anymore: 0.4066499173641205, sometimes: 0.427034467458725, anymore: 0.4066499173641205, when: 0.43749767541885376, when: 0.43749767541885376, when: 0.43749767541 ...
#
#
# This is a dictionary of words most similar to the word "panic" in "sixteen.txt".
# {alarm: 0.46710968017578125, alarm: 0.46710968017578125, alarm: 0.46710968017578125, alarm: 0.46710968017578125, trouble: 0.5293300747871399, when: 0.43749767541885376, happen: 0.43996116518974304, serious: 0.4416359066963196, happen: 0.43996116518974304, serious: 0.4416359066963196, problem: 0.439698725938797, startled: 0.4100424349308014, Wake: 0.5036436319351196, Wake: 0.5036436319351196, wake: 0.5036436319351196, moment: 0.44734853506088257, wake: 0.5036436319351196, wake: 0.5036436319351196, mental: 0.47315868735313416, hurry: 0.4101730287075043, When: 0.43749767541885376, when: 0.43749767541885376, Nervous: 0.5641590356826782, worried: 0.5002680420875549, nervous: 0.5641590356826782, worried: 0.5002680420875549, nervous: 0.5641590356826782, trembling: 0.4449595510959625, asleep: 0.43356144428253174, upset: 0.4269835650920868, terrible: 0.4448452889919281, reaction: 0.43779629468917847, feelings: 0.507344663143158, fury: 0.40807339549064636, emotions: 0.493652880191803, serious: 0.4416359066963196, mind: 0.4265080988407135, realize: 0.4097926616668701, happening: 0.40955767035484314, disturbed: 0.41646870970726013, disturbed: 0.41646870970726013, shaking: 0.4279182553291321, realize: 0.4097926616668701, disappear: 0.4180927872657776, disappear: 0.4180927872657776, feeling: 0.49194496870040894, bad: 0.4104759991168976, bad: 0.4104759991168976, angry: 0.44234710931777954, threatening: 0.41319841146469116, problem: 0.439698725938797, trying: 0.4293230473995209, moment: 0.44734853506088257, disbelief: 0.45602330565452576, anxious: 0.5846718549728394, anxious: 0.5846718549728394, dismay: 0.4640142619609833, startled: 0.4100424349308014, startled: 0.4100424349308014, sense: 0.40772420167922974, felt: 0.40701329708099365, happening: 0.40955767035484314, happening: 0.40955767035484314, Stop: 0.4402228891849518, reason: 0.40898850560188293, worst: 0.4175437390804291, sleep: 0.5002427697181702, paranoid: 0.5388026833534241, When: 0.43749767541885376, attention: 0.4063165783882141, experiencing: 0.49711257219314575, angry: 0.44234710931777954, depressed: 0.5231024622917175, trying: 0.4293230473995209, excitement: 0.4632132649421692, depressed: 0.5231024622917175, trying: 0.4293230473995209, When: 0.43749767541885376, moment: 0.44734853506088257, alarm: 0.46710968017578125, tragedy: 0.41304656863212585, crying: 0.5160260796546936, mind: 0.4265080988407135, terrible: 0.4448452889919281, pain: 0.5249786972999573, hurt: 0.41069528460502625, anger: 0.5936174392700195, terrible: 0.4448452889919281, pain: 0.5249786972999573, hurt: 0.41069528460502625, anger: 0.5936174392700195, when: 0.43749767541885376, worry: 0.5441118478775024, situation: 0.47141218185424805, brink: 0.41374385356903076, paranoid: 0.5388026833534241, realizing: 0.4036383330821991, crazy: 0.4205722212791443, bad: 0.4104759991168976, crazy: 0.4205722212791443, bad: 0.4104759991168976, crying: 0.5160260796546936, serious: 0.4416359066963196, disturbed: 0.41646870970726013, disturbed: 0.41646870970726013, confused: 0.44336220622062683, mood: 0.5084038972854614, mood: 0.5084038972854614, laughter: 0.4146808087825775, laughter: 0.4146808087825775, suddenly: 0.5244616866111755, sudden: 0.6243610978126526, frightened: 0.5243118405342102, angry: 0.44234710931777954, felt: 0.40701329708099365, brain: 0.41149720549583435, felt: 0.40701329708099365, embarrassed: 0.40131354331970215, embarrassed: 0.40131354331970215, hurt: 0.41069528460502625, feelings: 0.507344663143158, happen: 0.43996116518974304, serious: 0.4416359066963196, confused: 0.44336220622062683, mind: 0.4265080988407135, sort: 0.41327935457229614, mind: 0.4265080988407135, strange: 0.4092326760292053, problem: 0.439698725938797, shock: 0.47768935561180115, attention: 0.4063165783882141, when: 0.43749767541885376, attention: 0.4063165783882141, problem: 0.439698725938797, startled: 0.4100424349308014, guilt: 0.4704335331916809, nervous: 0.5641590356826782, crazy: 0.4205722212791443, strange: 0.4092326760292053, threat: 0 ...

# %% [markdown]
# #### "Dedupe" and sort the dictionary
# The results above give you duplicate words based on how often they appear in the text. That's information we might want to count, but still just have the word appear once. We might also want to sort the values from most to least similar to our word of interest.
#
# So we'll try to do these things in the next cell. The **Counter** function from the collections library will be super helpful here because it takes distinct values AND counts how often a value appears in the text.

# %%
from collections import Counter

def readTextFiles(filepath):
    with open(filepath, 'r', encoding='utf8') as f:
        readFile = f.read()
        # print(readFile)
        stringFile = str(readFile)

        tokens = nlp(stringFile)
        # playing with vectors here
        vectors = tokens.vector
        # Want to "see" some vector information? Uncomment the  next line:
        # print(vectors)

        wordOfInterest = nlp(u'school')

        # Our structures for storing similarity data:
        # This time we'll add counts, 
        # and we'll use Python's sorted() function to sort by similarity values from high (close to 1) to low (close to 0):
        highSimilarityDict = {}
        sorted_similarity = sorted(highSimilarityDict.items(), key=lambda item: item[1], reverse=True)
        wordCounts = Counter()
        
        for token in tokens:
            if(token and token.vector_norm):
                if wordOfInterest.similarity(token) > .4:
                    wordCounts[token.text] += 1
                # ^^^^ our "similarity gage" ^^^^
                    highSimilarityDict[token] = wordOfInterest.similarity(token)
                    # The line above creates the structure for each entry in my dictionary.
                        # print(token.text, "about this much similar to", wordOfInterest, ": ", wordOfInterest.similarity(token))
        # Smoke test for the Counter(): 
        # for word, count in list(wordCounts.items())[:5]:
        #    print(f"'{word}': {count}")
        print(f'This is a dictionary of words most similar to the word "{wordOfInterest.text}" in "{file}".')
        for word, similarity in highSimilarityDict.items():
            count = wordCounts[word.text]
            print(f"{word}: similarity={similarity:.3f}, count={count}")
            # The `:3f` above basically just reduces the decimal places to three (as in 3 floating points). 
            # print(f"{word}: similarity={similarity}, count={count}")
        print('\n')
 

for file in os.listdir(collection):
    if file.endswith(".txt"):
        filepath = f"{collection}/{file}"
        readTextFiles(filepath)
# Out:
# This is a dictionary of words most similar to the word "school" in "breakfast.txt".
# Club: similarity=0.431, count=3
# children: similarity=0.534, count=3
# they: similarity=0.410, count=23
# They: similarity=0.410, count=19
# they: similarity=0.410, count=23
# going: similarity=0.450, count=15
# HIGH: similarity=0.542, count=1
# SCHOOL: similarity=1.000, count=1
# DAY: similarity=0.440, count=43
# school: similarity=1.000, count=18
# High: similarity=0.542, count=1
# School: similarity=1.000, count=2
# But: similarity=0.405, count=7
# who: similarity=0.426, count=12
# care: similarity=0.414, count=9
# way: similarity=0.416, count=16
# DAY: similarity=0.440, count=43
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# class: similarity=0.534, count=1
# go: similarity=0.440, count=36
# day: similarity=0.440, count=4
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# school: similarity=1.000, count=18
# DAY: similarity=0.440, count=43
# there: similarity=0.425, count=33
# He: similarity=0.426, count=59
# first: similarity=0.400, count=7
# time: similarity=0.425, count=14
# time: similarity=0.425, count=14
# there: similarity=0.425, count=33
# time: similarity=0.425, count=14
# Mom: similarity=0.433, count=2
# study: similarity=0.418, count=2
# there: similarity=0.425, count=33
# way: similarity=0.416, count=16
# study: similarity=0.418, count=2
# go: similarity=0.440, count=36
# school: similarity=1.000, count=18
# DAY: similarity=0.440, count=43
# he: similarity=0.426, count=56
# there: similarity=0.425, count=33
# got: similarity=0.406, count=28
# Mom: similarity=0.433, count=2
# school: similarity=1.000, count=18
# scholarship: similarity=0.535, count=2
# discipline: similarity=0.421, count=1
# school: similarity=1.000, count=18
# DAY: similarity=0.440, count=43
# He: similarity=0.426, count=59
# but: similarity=0.405, count=29
# he: similarity=0.426, count=56
# She: similarity=0.461, count=18
# She: similarity=0.461, count=18
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# There: similarity=0.425, count=10
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# he: similarity=0.426, count=56
# there: similarity=0.425, count=33
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# where: similarity=0.444, count=7
# Library: similarity=0.447, count=1
# up: similarity=0.423, count=83
# where: similarity=0.444, count=7
# up: similarity=0.423, count=83
# She: similarity=0.461, count=18
# way: similarity=0.416, count=16
# library: similarity=0.447, count=8
# her: similarity=0.420, count=65
# teacher: similarity=0.758, count=2
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# got: similarity=0.406, count=28
# job: similarity=0.438, count=1
# time: similarity=0.425, count=14
# her: similarity=0.420, count=65
# there: similarity=0.425, count=33
# but: similarity=0.405, count=29
# care: similarity=0.414, count=9
# He: similarity=0.426, count=59
# she: similarity=0.461, count=15
# going: similarity=0.450, count=15
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# going: similarity=0.450, count=15
# who: similarity=0.426, count=12
# when: similarity=0.441, count=28
# up: similarity=0.423, count=83
# learn: similarity=0.415, count=2
# care: similarity=0.414, count=9
# He: similarity=0.426, count=59
# office: similarity=0.435, count=7
# hall: similarity=0.435, count=11
# He: similarity=0.426, count=59
# got: similarity=0.406, count=28
# young: similarity=0.466, count=4
# Everyone: similarity=0.408, count=11
# her: similarity=0.420, count=65
# he: similarity=0.426, count=56
# Everyone: similarity=0.408, count=11
# her: similarity=0.420, count=65
# lunch: similarity=0.410, count=8
# her: similarity=0.420, count=65
# office: similarity=0.435, count=7
# Who: similarity=0.426, count=9
# Who: similarity=0.426, count=9
# Who: similarity=0.426, count=9
# He: similarity=0.426, count=59
# time: similarity=0.425, count=14
# They: similarity=0.410, count=19
# way: similarity=0.416, count=16
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# who: similarity=0.426, count=12
# still: similarity=0.408, count=8
# up: similarity=0.423, count=83
# He: similarity=0.426, count=59
# but: similarity=0.405, count=29
# got: similarity=0.406, count=28
# go: similarity=0.440, count=36
# got: similarity=0.406, count=28
# go: similarity=0.440, count=36
# Everyone: similarity=0.408, count=11
# up: similarity=0.423, count=83
# first: similarity=0.400, count=7
# when: similarity=0.441, count=28
# He: similarity=0.426, count=59
# go: similarity=0.440, count=36
# up: similarity=0.423, count=83
# because: similarity=0.429, count=21
# He: similarity=0.426, count=59
# doing: similarity=0.404, count=14
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# Go: similarity=0.440, count=3
# OFFICE: similarity=0.435, count=3
# DAY: similarity=0.440, count=43
# office: similarity=0.435, count=7
# going: similarity=0.450, count=15
# there: similarity=0.425, count=33
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# They: similarity=0.410, count=19
# up: similarity=0.423, count=83
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# There: similarity=0.425, count=10
# Who: similarity=0.426, count=9
# school: similarity=1.000, count=18
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# prep: similarity=0.471, count=1
# club: similarity=0.431, count=11
# Student: similarity=0.740, count=1
# council: similarity=0.443, count=1
# they: similarity=0.410, count=23
# activities: similarity=0.425, count=3
# math: similarity=0.574, count=2
# club: similarity=0.431, count=11
# they: similarity=0.410, count=23
# activities: similarity=0.425, count=3
# but: similarity=0.405, count=29
# clubs: similarity=0.401, count=3
# he: similarity=0.426, count=56
# club: similarity=0.431, count=11
# math: similarity=0.574, count=2
# club: similarity=0.431, count=11
# club: similarity=0.431, count=11
# club: similarity=0.431, count=11
# club: similarity=0.431, count=11
# club: similarity=0.431, count=11
# academic: similarity=0.615, count=2
# club: similarity=0.431, count=11
# academic: similarity=0.615, count=2
# clubs: similarity=0.401, count=3
# clubs: similarity=0.401, count=3
# but: similarity=0.405, count=29
# they: similarity=0.410, count=23
# club: similarity=0.431, count=11
# but: similarity=0.405, count=29
# there: similarity=0.425, count=33
# children: similarity=0.534, count=3
# club: similarity=0.431, count=11
# year: similarity=0.487, count=5
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# but: similarity=0.405, count=29
# high: similarity=0.542, count=4
# high: similarity=0.542, count=4
# dad: similarity=0.439, count=5
# mom: similarity=0.433, count=4
# He: similarity=0.426, count=59
# got: similarity=0.406, count=28
# high: similarity=0.542, count=4
# he: similarity=0.426, count=56
# started: similarity=0.404, count=3
# he: similarity=0.426, count=56
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# got: similarity=0.406, count=28
# meet: similarity=0.437, count=2
# meet: similarity=0.437, count=2
# life: similarity=0.408, count=9
# because: similarity=0.429, count=21
# but: similarity=0.405, count=29
# up: similarity=0.423, count=83
# They: similarity=0.410, count=19
# hall: similarity=0.435, count=11
# He: similarity=0.426, count=59
# office: similarity=0.435, count=7
# up: similarity=0.423, count=83
# He: similarity=0.426, count=59
# library: similarity=0.447, count=8
# there: similarity=0.425, count=33
# Young: similarity=0.466, count=1
# He: similarity=0.426, count=59
# DAY: similarity=0.440, count=43
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# way: similarity=0.416, count=16
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# library: similarity=0.447, count=8
# school: similarity=1.000, count=18
# there: similarity=0.425, count=33
# Everyone: similarity=0.408, count=11
# DAY: similarity=0.440, count=43
# office: similarity=0.435, count=7
# He: similarity=0.426, count=59
# doing: similarity=0.404, count=14
# up: similarity=0.423, count=83
# there: similarity=0.425, count=33
# up: similarity=0.423, count=83
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# hall: similarity=0.435, count=11
# He: similarity=0.426, count=59
# they: similarity=0.410, count=23
# Who: similarity=0.426, count=9
# Who: similarity=0.426, count=9
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# fall: similarity=0.440, count=2
# time: similarity=0.425, count=14
# place: similarity=0.410, count=3
# young: similarity=0.466, count=4
# He: similarity=0.426, count=59
# way: similarity=0.416, count=16
# They: similarity=0.410, count=19
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# go: similarity=0.440, count=36
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# They: similarity=0.410, count=19
# but: similarity=0.405, count=29
# there: similarity=0.425, count=33
# children: similarity=0.534, count=3
# career: similarity=0.434, count=2
# He: similarity=0.426, count=59
# doing: similarity=0.404, count=14
# school: similarity=1.000, count=18
# library: similarity=0.447, count=8
# library: similarity=0.447, count=8
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# varsity: similarity=0.496, count=1
# there: similarity=0.425, count=33
# after: similarity=0.406, count=6
# going: similarity=0.450, count=15
# doing: similarity=0.404, count=14
# got: similarity=0.406, count=28
# life: similarity=0.408, count=9
# got: similarity=0.406, count=28
# got: similarity=0.406, count=28
# there: similarity=0.425, count=33
# got: similarity=0.406, count=28
# there: similarity=0.425, count=33
# when: similarity=0.441, count=28
# first: similarity=0.400, count=7
# came: similarity=0.414, count=4
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# time: similarity=0.425, count=14
# time: similarity=0.425, count=14
# everyone: similarity=0.408, count=4
# going: similarity=0.450, count=15
# outside: similarity=0.414, count=2
# time: similarity=0.425, count=14
# thinking: similarity=0.402, count=6
# her: similarity=0.420, count=65
# He: similarity=0.426, count=59
# football: similarity=0.488, count=2
# He: similarity=0.426, count=59
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# everyone: similarity=0.408, count=4
# fall: similarity=0.440, count=2
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# there: similarity=0.425, count=33
# kids: similarity=0.627, count=9
# up: similarity=0.423, count=83
# Who: similarity=0.426, count=9
# go: similarity=0.440, count=36
# Everyone: similarity=0.408, count=11
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# work: similarity=0.434, count=3
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# when: similarity=0.441, count=28
# mom: similarity=0.433, count=4
# but: similarity=0.405, count=29
# dad: similarity=0.439, count=5
# her: similarity=0.420, count=65
# parents: similarity=0.586, count=11
# go: similarity=0.440, count=36
# because: similarity=0.429, count=21
# because: similarity=0.429, count=21
# There: similarity=0.425, count=10
# Who: similarity=0.426, count=9
# old: similarity=0.410, count=10
# mom: similarity=0.433, count=4
# They: similarity=0.410, count=19
# go: similarity=0.440, count=36
# they: similarity=0.410, count=23
# Everyone: similarity=0.408, count=11
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# parents: similarity=0.586, count=11
# But: similarity=0.405, count=7
# parents: similarity=0.586, count=11
# school: similarity=1.000, count=18
# middle: similarity=0.555, count=4
# up: similarity=0.423, count=83
# he: similarity=0.426, count=56
# parents: similarity=0.586, count=11
# parent: similarity=0.424, count=1
# up: similarity=0.423, count=83
# But: similarity=0.405, count=7
# doing: similarity=0.404, count=14
# he: similarity=0.426, count=56
# got: similarity=0.406, count=28
# family: similarity=0.403, count=5
# girl: similarity=0.476, count=4
# but: similarity=0.405, count=29
# but: similarity=0.405, count=29
# there: similarity=0.425, count=33
# There: similarity=0.425, count=10
# there: similarity=0.425, count=33
# but: similarity=0.405, count=29
# they: similarity=0.410, count=23
# when: similarity=0.441, count=28
# He: similarity=0.426, count=59
# girl: similarity=0.476, count=4
# up: similarity=0.423, count=83
# boy: similarity=0.480, count=2
# up: similarity=0.423, count=83
# parents: similarity=0.586, count=11
# past: similarity=0.451, count=2
# school: similarity=1.000, count=18
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# where: similarity=0.444, count=7
# friends: similarity=0.432, count=19
# but: similarity=0.405, count=29
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# parents: similarity=0.586, count=11
# care: similarity=0.414, count=9
# He: similarity=0.426, count=59
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# doing: similarity=0.404, count=14
# dad: similarity=0.439, count=5
# because: similarity=0.429, count=21
# career: similarity=0.434, count=2
# arts: similarity=0.529, count=1
# but: similarity=0.405, count=29
# after: similarity=0.406, count=6
# past: similarity=0.451, count=2
# years: similarity=0.439, count=4
# learned: similarity=0.455, count=1
# but: similarity=0.405, count=29
# institution: similarity=0.468, count=1
# friends: similarity=0.432, count=19
# way: similarity=0.416, count=16
# Everyone: similarity=0.408, count=11
# OFFICE: similarity=0.435, count=3
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# girls: similarity=0.568, count=3
# lunch: similarity=0.410, count=8
# cafeteria: similarity=0.482, count=2
# place: similarity=0.410, count=3
# lunch: similarity=0.410, count=8
# care: similarity=0.414, count=9
# her: similarity=0.420, count=65
# there: similarity=0.425, count=33
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# go: similarity=0.440, count=36
# home: similarity=0.445, count=8
# up: similarity=0.423, count=83
# There: similarity=0.425, count=10
# teacher: similarity=0.758, count=2
# go: similarity=0.440, count=36
# DAY: similarity=0.440, count=43
# hall: similarity=0.435, count=11
# still: similarity=0.408, count=8
# When: similarity=0.441, count=8
# They: similarity=0.410, count=19
# because: similarity=0.429, count=21
# because: similarity=0.429, count=21
# coach: similarity=0.416, count=1
# because: similarity=0.429, count=21
# Coach: similarity=0.416, count=1
# old: similarity=0.410, count=10
# because: similarity=0.429, count=21
# because: similarity=0.429, count=21
# got: similarity=0.406, count=28
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# he: similarity=0.426, count=56
# her: similarity=0.420, count=65
# he: similarity=0.426, count=56
# doing: similarity=0.404, count=14
# When: similarity=0.441, count=8
# She: similarity=0.461, count=18
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# who: similarity=0.426, count=12
# still: similarity=0.408, count=8
# girls: similarity=0.568, count=3
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# but: similarity=0.405, count=29
# because: similarity=0.429, count=21
# her: similarity=0.420, count=65
# Because: similarity=0.429, count=1
# doing: similarity=0.404, count=14
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# there: similarity=0.425, count=33
# where: similarity=0.444, count=7
# lunch: similarity=0.410, count=8
# who: similarity=0.426, count=12
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# up: similarity=0.423, count=83
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# She: similarity=0.461, count=18
# She: similarity=0.461, count=18
# lunch: similarity=0.410, count=8
# lunch: similarity=0.410, count=8
# He: similarity=0.426, count=59
# lunch: similarity=0.410, count=8
# mom: similarity=0.433, count=4
# life: similarity=0.408, count=9
# house: similarity=0.417, count=2
# Dad: similarity=0.439, count=6
# day: similarity=0.440, count=4
# Dad: similarity=0.439, count=6
# go: similarity=0.440, count=36
# Dad: similarity=0.439, count=6
# but: similarity=0.405, count=29
# got: similarity=0.406, count=28
# homework: similarity=0.531, count=2
# life: similarity=0.408, count=9
# family: similarity=0.403, count=5
# up: similarity=0.423, count=83
# Go: similarity=0.440, count=3
# Dad: similarity=0.439, count=6
# Dad: similarity=0.439, count=6
# Dad: similarity=0.439, count=6
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# house: similarity=0.417, count=2
# when: similarity=0.441, count=28
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# he: similarity=0.426, count=56
# OFFICE: similarity=0.435, count=3
# DAY: similarity=0.440, count=43
# DAY: similarity=0.440, count=43
# they: similarity=0.410, count=23
# library: similarity=0.447, count=8
# where: similarity=0.444, count=7
# went: similarity=0.468, count=2
# when: similarity=0.441, count=28
# he: similarity=0.426, count=56
# going: similarity=0.450, count=15
# doing: similarity=0.404, count=14
# boy: similarity=0.480, count=2
# after: similarity=0.406, count=6
# up: similarity=0.423, count=83
# who: similarity=0.426, count=12
# there: similarity=0.425, count=33
# her: similarity=0.420, count=65
# hall: similarity=0.435, count=11
# he: similarity=0.426, count=56
# Where: similarity=0.444, count=4
# going: similarity=0.450, count=15
# They: similarity=0.410, count=19
# they: similarity=0.410, count=23
# go: similarity=0.440, count=36
# cafeteria: similarity=0.482, count=2
# activities: similarity=0.425, count=3
# hall: similarity=0.435, count=11
# going: similarity=0.450, count=15
# way: similarity=0.416, count=16
# They: similarity=0.410, count=19
# go: similarity=0.440, count=36
# way: similarity=0.416, count=16
# hall: similarity=0.435, count=11
# library: similarity=0.447, count=8
# he: similarity=0.426, count=56
# gym: similarity=0.460, count=1
# going: similarity=0.450, count=15
# up: similarity=0.423, count=83
# He: similarity=0.426, count=59
# doing: similarity=0.404, count=14
# thinking: similarity=0.402, count=6
# scholarship: similarity=0.535, count=2
# He: similarity=0.426, count=59
# who: similarity=0.426, count=12
# They: similarity=0.410, count=19
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# kids: similarity=0.627, count=9
# when: similarity=0.441, count=28
# go: similarity=0.440, count=36
# everyone: similarity=0.408, count=4
# go: similarity=0.440, count=36
# gymnasium: similarity=0.409, count=1
# going: similarity=0.450, count=15
# day: similarity=0.440, count=4
# they: similarity=0.410, count=23
# home: similarity=0.445, count=8
# family: similarity=0.403, count=5
# he: similarity=0.426, count=56
# he: similarity=0.426, count=56
# he: similarity=0.426, count=56
# go: similarity=0.440, count=36
# years: similarity=0.439, count=4
# he: similarity=0.426, count=56
# go: similarity=0.440, count=36
# but: similarity=0.405, count=29
# way: similarity=0.416, count=16
# DAY: similarity=0.440, count=43
# there: similarity=0.425, count=33
# time: similarity=0.425, count=14
# time: similarity=0.425, count=14
# kids: similarity=0.627, count=9
# year: similarity=0.487, count=5
# home: similarity=0.445, count=8
# But: similarity=0.405, count=7
# When: similarity=0.441, count=8
# place: similarity=0.410, count=3
# they: similarity=0.410, count=23
# up: similarity=0.423, count=83
# life: similarity=0.408, count=9
# there: similarity=0.425, count=33
# They: similarity=0.410, count=19
# first: similarity=0.400, count=7
# go: similarity=0.440, count=36
# first: similarity=0.400, count=7
# there: similarity=0.425, count=33
# after: similarity=0.406, count=6
# DAY: similarity=0.440, count=43
# She: similarity=0.461, count=18
# he: similarity=0.426, count=56
# DAY: similarity=0.440, count=43
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# hall: similarity=0.435, count=11
# going: similarity=0.450, count=15
# office: similarity=0.435, count=7
# young: similarity=0.466, count=4
# He: similarity=0.426, count=59
# up: similarity=0.423, count=83
# He: similarity=0.426, count=59
# her: similarity=0.420, count=65
# He: similarity=0.426, count=59
# there: similarity=0.425, count=33
# She: similarity=0.461, count=18
# her: similarity=0.420, count=65
# Everyone: similarity=0.408, count=11
# time: similarity=0.425, count=14
# but: similarity=0.405, count=29
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# still: similarity=0.408, count=8
# Everyone: similarity=0.408, count=11
# who: similarity=0.426, count=12
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# after: similarity=0.406, count=6
# DAY: similarity=0.440, count=43
# go: similarity=0.440, count=36
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# school: similarity=1.000, count=18
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# DAY: similarity=0.440, count=43
# school: similarity=1.000, count=18
# history: similarity=0.417, count=1
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# doing: similarity=0.404, count=14
# homework: similarity=0.531, count=2
# Homework: similarity=0.531, count=1
# Got: similarity=0.406, count=1
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# library: similarity=0.447, count=8
# got: similarity=0.406, count=28
# middle: similarity=0.555, count=4
# she: similarity=0.461, count=15
# she: similarity=0.461, count=15
# middle: similarity=0.555, count=4
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# her: similarity=0.420, count=65
# there: similarity=0.425, count=33
# He: similarity=0.426, count=59
# got: similarity=0.406, count=28
# there: similarity=0.425, count=33
# he: similarity=0.426, count=56
# girl: similarity=0.476, count=4
# way: similarity=0.416, count=16
# He: similarity=0.426, count=59
# got: similarity=0.406, count=28
# got: similarity=0.406, count=28
# first: similarity=0.400, count=7
# where: similarity=0.444, count=7
# up: similarity=0.423, count=83
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# when: similarity=0.441, count=28
# home: similarity=0.445, count=8
# life: similarity=0.408, count=9
# because: similarity=0.429, count=21
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# her: similarity=0.420, count=65
# she: similarity=0.461, count=15
# because: similarity=0.429, count=21
# her: similarity=0.420, count=65
# home: similarity=0.445, count=8
# life: similarity=0.408, count=9
# everyone: similarity=0.408, count=4
# home: similarity=0.445, count=8
# there: similarity=0.425, count=33
# parents: similarity=0.586, count=11
# But: similarity=0.405, count=7
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# There: similarity=0.425, count=10
# up: similarity=0.423, count=83
# girl: similarity=0.476, count=4
# up: similarity=0.423, count=83
# after: similarity=0.406, count=6
# her: similarity=0.420, count=65
# Go: similarity=0.440, count=3
# Where: similarity=0.444, count=4
# go: similarity=0.440, count=36
# GO: similarity=0.440, count=1
# but: similarity=0.405, count=29
# Parents: similarity=0.586, count=1
# they: similarity=0.410, count=23
# They: similarity=0.410, count=19
# They: similarity=0.410, count=19
# DAY: similarity=0.440, count=43
# when: similarity=0.441, count=28
# young: similarity=0.466, count=4
# When: similarity=0.441, count=8
# kid: similarity=0.574, count=2
# teaching: similarity=0.667, count=2
# years: similarity=0.439, count=4
# year: similarity=0.487, count=5
# kids: similarity=0.627, count=9
# kids: similarity=0.627, count=9
# took: similarity=0.425, count=1
# teaching: similarity=0.667, count=2
# summer: similarity=0.511, count=1
# work: similarity=0.434, count=3
# kids: similarity=0.627, count=9
# they: similarity=0.410, count=23
# kids: similarity=0.627, count=9
# when: similarity=0.441, count=28
# old: similarity=0.410, count=10
# kids: similarity=0.627, count=9
# when: similarity=0.441, count=28
# old: similarity=0.410, count=10
# they: similarity=0.410, count=23
# up: similarity=0.423, count=83
# middle: similarity=0.555, count=4
# when: similarity=0.441, count=28
# kids: similarity=0.627, count=9
# care: similarity=0.414, count=9
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# They: similarity=0.410, count=19
# school: similarity=1.000, count=18
# course: similarity=0.502, count=2
# school: similarity=1.000, count=18
# school: similarity=1.000, count=18
# They: similarity=0.410, count=19
# her: similarity=0.420, count=65
# there: similarity=0.425, count=33
# her: similarity=0.420, count=65
# parents: similarity=0.586, count=11
# he: similarity=0.426, count=56
# when: similarity=0.441, count=28
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# He: similarity=0.426, count=59
# adult: similarity=0.413, count=1
# he: similarity=0.426, count=56
# her: similarity=0.420, count=65
# first: similarity=0.400, count=7
# First: similarity=0.400, count=1
# he: similarity=0.426, count=56
# she: similarity=0.461, count=15
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# life: similarity=0.408, count=9
# but: similarity=0.405, count=29
# but: similarity=0.405, count=29
# when: similarity=0.441, count=28
# She: similarity=0.461, count=18
# girls: similarity=0.568, count=3
# She: similarity=0.461, count=18
# she: similarity=0.461, count=15
# she: similarity=0.461, count=15
# way: similarity=0.416, count=16
# day: similarity=0.440, count=4
# when: similarity=0.441, count=28
# because: similarity=0.429, count=21
# she: similarity=0.461, count=15
# got: similarity=0.406, count=28
# but: similarity=0.405, count=29
# He: similarity=0.426, count=59
# She: similarity=0.461, count=18
# he: similarity=0.426, count=56
# when: similarity=0.441, count=28
# they: similarity=0.410, count=23
# came: similarity=0.414, count=4
# old: similarity=0.410, count=10
# kid: similarity=0.574, count=2
# because: similarity=0.429, count=21
# He: similarity=0.426, count=59
# going: similarity=0.450, count=15
# when: similarity=0.441, count=28
# he: similarity=0.426, count=56
# school: similarity=1.000, count=18
# he: similarity=0.426, count=56
# got: similarity=0.406, count=28
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# he: similarity=0.426, count=56
# he: similarity=0.426, count=56
# started: similarity=0.404, count=3
# thinking: similarity=0.402, count=6
# started: similarity=0.404, count=3
# friends: similarity=0.432, count=19
# they: similarity=0.410, count=23
# when: similarity=0.441, count=28
# office: similarity=0.435, count=7
# go: similarity=0.440, count=36
# home: similarity=0.445, count=8
# he: similarity=0.426, count=56
# he: similarity=0.426, count=56
# There: similarity=0.425, count=10
# way: similarity=0.416, count=16
# because: similarity=0.429, count=21
# old: similarity=0.410, count=10
# He: similarity=0.426, count=59
# he: similarity=0.426, count=56
# got: similarity=0.406, count=28
# family: similarity=0.403, count=5
# he: similarity=0.426, count=56
# old: similarity=0.410, count=10
# old: similarity=0.410, count=10
# go: similarity=0.440, count=36
# grades: similarity=0.583, count=1
# when: similarity=0.441, count=28
# when: similarity=0.441, count=28
# outside: similarity=0.414, count=2
# when: similarity=0.441, count=28
# when: similarity=0.441, count=28
# when: similarity=0.441, count=28
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# got: similarity=0.406, count=28
# got: similarity=0.406, count=28
# life: similarity=0.408, count=9
# When: similarity=0.441, count=8
# up: similarity=0.423, count=83
# course: similarity=0.502, count=2
# way: similarity=0.416, count=16
# grade: similarity=0.580, count=2
# because: similarity=0.429, count=21
# because: similarity=0.429, count=21
# care: similarity=0.414, count=9
# there: similarity=0.425, count=33
# there: similarity=0.425, count=33
# There: similarity=0.425, count=10
# way: similarity=0.416, count=16
# doing: similarity=0.404, count=14
# years: similarity=0.439, count=4
# but: similarity=0.405, count=29
# doing: similarity=0.404, count=14
# She: similarity=0.461, count=18
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# When: similarity=0.441, count=8
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# Everyone: similarity=0.408, count=11
# Where: similarity=0.444, count=4
# learn: similarity=0.415, count=2
# Camp: similarity=0.487, count=1
# grade: similarity=0.580, count=2
# her: similarity=0.420, count=65
# he: similarity=0.426, count=56
# home: similarity=0.445, count=8
# care: similarity=0.414, count=9
# school: similarity=1.000, count=18
# remember: similarity=0.423, count=1
# he: similarity=0.426, count=56
# when: similarity=0.441, count=28
# got: similarity=0.406, count=28
# got: similarity=0.406, count=28
# School: similarity=1.000, count=2
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# up: similarity=0.423, count=83
# they: similarity=0.410, count=23
# work: similarity=0.434, count=3
# up: similarity=0.423, count=83
# he: similarity=0.426, count=56
# got: similarity=0.406, count=28
# year: similarity=0.487, count=5
# year: similarity=0.487, count=5
# old: similarity=0.410, count=10
# family: similarity=0.403, count=5
# got: similarity=0.406, count=28
# old: similarity=0.410, count=10
# up: similarity=0.423, count=83
# go: similarity=0.440, count=36
# There: similarity=0.425, count=10
# parents: similarity=0.586, count=11
# When: similarity=0.441, count=8
# up: similarity=0.423, count=83
# Who: similarity=0.426, count=9
# care: similarity=0.414, count=9
# thinking: similarity=0.402, count=6
# time: similarity=0.425, count=14
# but: similarity=0.405, count=29
# When: similarity=0.441, count=8
# friends: similarity=0.432, count=19
# still: similarity=0.408, count=8
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# came: similarity=0.414, count=4
# up: similarity=0.423, count=83
# hall: similarity=0.435, count=11
# there: similarity=0.425, count=33
# sports: similarity=0.442, count=1
# when: similarity=0.441, count=28
# he: similarity=0.426, count=56
# up: similarity=0.423, count=83
# friends: similarity=0.432, count=19
# way: similarity=0.416, count=16
# came: similarity=0.414, count=4
# up: similarity=0.423, count=83
# got: similarity=0.406, count=28
# up: similarity=0.423, count=83
# friends: similarity=0.432, count=19
# who: similarity=0.426, count=12
# lunch: similarity=0.410, count=8
# high: similarity=0.542, count=4
# friends: similarity=0.432, count=19
# hall: similarity=0.435, count=11
# They: similarity=0.410, count=19
# doing: similarity=0.404, count=14
# they: similarity=0.410, count=23
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# up: similarity=0.423, count=83
# when: similarity=0.441, count=28
# school: similarity=1.000, count=18
# There: similarity=0.425, count=10
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# because: similarity=0.429, count=21
# they: similarity=0.410, count=23
# up: similarity=0.423, count=83
# her: similarity=0.420, count=65
# go: similarity=0.440, count=36
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# friends: similarity=0.432, count=19
# they: similarity=0.410, count=23
# because: similarity=0.429, count=21
# he: similarity=0.426, count=56
# because: similarity=0.429, count=21
# go: similarity=0.440, count=36
# go: similarity=0.440, count=36
# up: similarity=0.423, count=83
# parents: similarity=0.586, count=11
# semester: similarity=0.554, count=1
# still: similarity=0.408, count=8
# went: similarity=0.468, count=2
# They: similarity=0.410, count=19
# Everyone: similarity=0.408, count=11
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# DAY: similarity=0.440, count=43
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# but: similarity=0.405, count=29
# but: similarity=0.405, count=29
# but: similarity=0.405, count=29
# who: similarity=0.426, count=12
# who: similarity=0.426, count=12
# Where: similarity=0.444, count=4
# going: similarity=0.450, count=15
# up: similarity=0.423, count=83
# go: similarity=0.440, count=36
# her: similarity=0.420, count=65
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# her: similarity=0.420, count=65
# up: similarity=0.423, count=83
# thinking: similarity=0.402, count=6
# he: similarity=0.426, count=56
# going: similarity=0.450, count=15
# thinking: similarity=0.402, count=6
# still: similarity=0.408, count=8
# up: similarity=0.423, count=83
# still: similarity=0.408, count=8
# DAY: similarity=0.440, count=43
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# when: similarity=0.441, count=28
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# DAY: similarity=0.440, count=43
# she: similarity=0.461, count=15
# parents: similarity=0.586, count=11
# time: similarity=0.425, count=14
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# DAY: similarity=0.440, count=43
# hall: similarity=0.435, count=11
# where: similarity=0.444, count=7
# they: similarity=0.410, count=23
# up: similarity=0.423, count=83
# DAY: similarity=0.440, count=43
# dad: similarity=0.439, count=5
# dad: similarity=0.439, count=5
# they: similarity=0.410, count=23
# her: similarity=0.420, count=65
# They: similarity=0.410, count=19
# she: similarity=0.461, count=15
# her: similarity=0.420, count=65
# She: similarity=0.461, count=18
# LIBRARY: similarity=0.447, count=19
# DAY: similarity=0.440, count=43
# up: similarity=0.423, count=83
# But: similarity=0.405, count=7
# who: similarity=0.426, count=12
# FOOTBALL: similarity=0.488, count=1
# DAY: similarity=0.440, count=43
# But: similarity=0.405, count=7
# Club: similarity=0.431, count=3
# football: similarity=0.488, count=2
# he: similarity=0.426, count=56
# there: similarity=0.425, count=33
# Club: similarity=0.431, count=3
# Hall: similarity=0.435, count=1
#
#
# This is a dictionary of words most similar to the word "school" in "sixteen.txt".
# middle: similarity=0.555, count=5
# class: similarity=0.534, count=5
# early: similarity=0.404, count=4
# old: similarity=0.410, count=20
# house: similarity=0.417, count=34
# HOUSE: similarity=0.417, count=48
# house: similarity=0.417, count=34
# middle: similarity=0.555, count=5
# class: similarity=0.534, count=5
# early: similarity=0.404, count=4
# HOUSE: similarity=0.417, count=48
# old: similarity=0.410, count=20
# house: similarity=0.417, count=34
# HOUSE: similarity=0.417, count=48
# house: similarity=0.417, count=34
# family: similarity=0.403, count=12
# activities: similarity=0.425, count=1
# There: similarity=0.425, count=18
# go: similarity=0.440, count=37
# got: similarity=0.406, count=38
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# He: similarity=0.426, count=244
# young: similarity=0.466, count=8
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# Dad: similarity=0.439, count=6
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# past: similarity=0.451, count=6
# he: similarity=0.426, count=70
# Dad: similarity=0.439, count=6
# her: similarity=0.420, count=373
# but: similarity=0.405, count=26
# her: similarity=0.420, count=373
# when: similarity=0.441, count=9
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# hall: similarity=0.435, count=16
# He: similarity=0.426, count=244
# there: similarity=0.425, count=16
# first: similarity=0.400, count=11
# her: similarity=0.420, count=373
# He: similarity=0.426, count=244
# there: similarity=0.425, count=16
# first: similarity=0.400, count=11
# her: similarity=0.420, count=373
# got: similarity=0.406, count=38
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# Dad: similarity=0.439, count=6
# Where: similarity=0.444, count=17
# school: similarity=1.000, count=13
# time: similarity=0.425, count=20
# school: similarity=1.000, count=13
# time: similarity=0.425, count=20
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# HOUSE: similarity=0.417, count=48
# girl: similarity=0.476, count=27
# HOUSE: similarity=0.417, count=48
# girl: similarity=0.476, count=27
# first: similarity=0.400, count=11
# Her: similarity=0.420, count=19
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# house: similarity=0.417, count=34
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# young: similarity=0.466, count=8
# young: similarity=0.466, count=8
# girl: similarity=0.476, count=27
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# still: similarity=0.408, count=23
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# summer: similarity=0.511, count=3
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# still: similarity=0.408, count=23
# up: similarity=0.423, count=166
# up: similarity=0.423, count=166
# state: similarity=0.472, count=1
# family: similarity=0.403, count=12
# school: similarity=1.000, count=13
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# HOUSE: similarity=0.417, count=48
# hall: similarity=0.435, count=16
# her: similarity=0.420, count=373
# HOUSE: similarity=0.417, count=48
# HALL: similarity=0.435, count=2
# hall: similarity=0.435, count=16
# her: similarity=0.420, count=373
# work: similarity=0.434, count=3
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# first: similarity=0.400, count=11
# day: similarity=0.440, count=4
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# HOUSE: similarity=0.417, count=48
# He: similarity=0.426, count=244
# remember: similarity=0.423, count=8
# HOUSE: similarity=0.417, count=48
# He: similarity=0.426, count=244
# Where: similarity=0.444, count=17
# He: similarity=0.426, count=244
# Where: similarity=0.444, count=17
# Where: similarity=0.444, count=17
# Where: similarity=0.444, count=17
# He: similarity=0.426, count=244
# but: similarity=0.405, count=26
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# They: similarity=0.410, count=45
# still: similarity=0.408, count=23
# going: similarity=0.450, count=38
# club: similarity=0.431, count=6
# learn: similarity=0.415, count=2
# they: similarity=0.410, count=28
# When: similarity=0.441, count=5
# time: similarity=0.425, count=20
# Who: similarity=0.426, count=13
# lunch: similarity=0.410, count=3
# time: similarity=0.425, count=20
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# go: similarity=0.440, count=37
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# way: similarity=0.416, count=12
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# when: similarity=0.441, count=9
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# They: similarity=0.410, count=45
# HIGH: similarity=0.542, count=3
# SCHOOL: similarity=1.000, count=16
# high: similarity=0.542, count=5
# school: similarity=1.000, count=13
# up: similarity=0.423, count=166
# HIGH: similarity=0.542, count=3
# SCHOOL: similarity=1.000, count=16
# high: similarity=0.542, count=5
# school: similarity=1.000, count=13
# HIGH: similarity=0.542, count=3
# SCHOOL: similarity=1.000, count=16
# young: similarity=0.466, count=8
# past: similarity=0.451, count=6
# boys: similarity=0.588, count=15
# girl: similarity=0.476, count=27
# up: similarity=0.423, count=166
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# STUDY: similarity=0.418, count=4
# study: similarity=0.418, count=3
# hall: similarity=0.435, count=16
# teacher: similarity=0.758, count=2
# class: similarity=0.534, count=5
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# taking: similarity=0.402, count=4
# SENIOR: similarity=0.475, count=2
# senior: similarity=0.475, count=8
# He: similarity=0.426, count=244
# STUDY: similarity=0.418, count=4
# study: similarity=0.418, count=3
# hall: similarity=0.435, count=16
# teacher: similarity=0.758, count=2
# class: similarity=0.534, count=5
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# taking: similarity=0.402, count=4
# SENIOR: similarity=0.475, count=2
# BOY: similarity=0.480, count=3
# senior: similarity=0.475, count=8
# He: similarity=0.426, count=244
# class: similarity=0.534, count=5
# student: similarity=0.740, count=2
# He: similarity=0.426, count=244
# study: similarity=0.418, count=3
# hall: similarity=0.435, count=16
# She: similarity=0.461, count=304
# Her: similarity=0.420, count=19
# STUDY: similarity=0.418, count=4
# She: similarity=0.461, count=304
# STUDY: similarity=0.418, count=4
# HALL: similarity=0.435, count=2
# She: similarity=0.461, count=304
# WHO: similarity=0.426, count=1
# CLASS: similarity=0.534, count=2
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# CLASSROOM: similarity=0.675, count=4
# He: similarity=0.426, count=244
# still: similarity=0.408, count=23
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# CLASS: similarity=0.534, count=2
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# CLASSROOM: similarity=0.675, count=4
# He: similarity=0.426, count=244
# still: similarity=0.408, count=23
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Her: similarity=0.420, count=19
# she: similarity=0.461, count=105
# Her: similarity=0.420, count=19
# CLASSROOM: similarity=0.675, count=4
# She: similarity=0.461, count=304
# CLASSROOM: similarity=0.675, count=4
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# writing: similarity=0.412, count=2
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# while: similarity=0.409, count=2
# SCHOOL: similarity=1.000, count=16
# hall: similarity=0.435, count=16
# SCHOOL: similarity=1.000, count=16
# hall: similarity=0.435, count=16
# Child: similarity=0.513, count=1
# her: similarity=0.420, count=373
# but: similarity=0.405, count=26
# who: similarity=0.426, count=23
# who: similarity=0.426, count=23
# Who: similarity=0.426, count=13
# He: similarity=0.426, count=244
# But: similarity=0.405, count=14
# He: similarity=0.426, count=244
# senior: similarity=0.475, count=8
# he: similarity=0.426, count=70
# He: similarity=0.426, count=244
# but: similarity=0.405, count=26
# got: similarity=0.406, count=38
# They: similarity=0.410, count=45
# CAFETERIA: similarity=0.482, count=6
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# CAFETERIA: similarity=0.482, count=6
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# CAFETERIA: similarity=0.482, count=6
# They: similarity=0.410, count=45
# hall: similarity=0.435, count=16
# CAFETERIA: similarity=0.482, count=6
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# CAFETERIA: similarity=0.482, count=6
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# CAFETERIA: similarity=0.482, count=6
# her: similarity=0.420, count=373
# going: similarity=0.450, count=38
# school: similarity=1.000, count=13
# They: similarity=0.410, count=45
# they: similarity=0.410, count=28
# started: similarity=0.404, count=1
# busy: similarity=0.401, count=2
# she: similarity=0.461, count=105
# remember: similarity=0.423, count=8
# her: similarity=0.420, count=373
# remember: similarity=0.423, count=8
# they: similarity=0.410, count=28
# he: similarity=0.426, count=70
# way: similarity=0.416, count=12
# he: similarity=0.426, count=70
# Girls: similarity=0.568, count=3
# life: similarity=0.408, count=8
# time: similarity=0.425, count=20
# boys: similarity=0.588, count=15
# up: similarity=0.423, count=166
# boy: similarity=0.480, count=12
# go: similarity=0.440, count=37
# She: similarity=0.461, count=304
# There: similarity=0.425, count=18
# there: similarity=0.425, count=16
# up: similarity=0.423, count=166
# There: similarity=0.425, count=18
# her: similarity=0.420, count=373
# Study: similarity=0.418, count=1
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# way: similarity=0.416, count=12
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# he: similarity=0.426, count=70
# she: similarity=0.461, count=105
# going: similarity=0.450, count=38
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# young: similarity=0.466, count=8
# up: similarity=0.423, count=166
# got: similarity=0.406, count=38
# She: similarity=0.461, count=304
# going: similarity=0.450, count=38
# her: similarity=0.420, count=373
# year: similarity=0.487, count=8
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# thinking: similarity=0.402, count=3
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# girl: similarity=0.476, count=27
# care: similarity=0.414, count=3
# She: similarity=0.461, count=304
# park: similarity=0.412, count=1
# but: similarity=0.405, count=26
# up: similarity=0.423, count=166
# but: similarity=0.405, count=26
# He: similarity=0.426, count=244
# go: similarity=0.440, count=37
# boys: similarity=0.588, count=15
# doing: similarity=0.404, count=8
# GIRL: similarity=0.476, count=6
# Girls: similarity=0.568, count=3
# after: similarity=0.406, count=15
# gym: similarity=0.460, count=19
# GIRL: similarity=0.476, count=6
# Girls: similarity=0.568, count=3
# after: similarity=0.406, count=15
# gym: similarity=0.460, count=19
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# studies: similarity=0.406, count=4
# senior: similarity=0.475, count=8
# girls: similarity=0.568, count=9
# her: similarity=0.420, count=373
# They: similarity=0.410, count=45
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# time: similarity=0.425, count=20
# Her: similarity=0.420, count=19
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# ...
# He: similarity=0.426, count=244
# taking: similarity=0.402, count=4
# practice: similarity=0.441, count=1
# up: similarity=0.423, count=166
# he: similarity=0.426, count=70
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# busy: similarity=0.401, count=2
# he: similarity=0.426, count=70
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Mom: similarity=0.433, count=6
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# Who: similarity=0.426, count=13
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# HER: similarity=0.420, count=6
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# Old: similarity=0.410, count=1
# go: similarity=0.440, count=37
# way: similarity=0.416, count=12
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# Dad: similarity=0.439, count=6
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# going: similarity=0.450, count=38
# go: similarity=0.440, count=37
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# going: similarity=0.450, count=38
# but: similarity=0.405, count=26
# dance: similarity=0.434, count=22
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# HOUSE: similarity=0.417, count=48
# up: similarity=0.423, count=166
# HOUSE: similarity=0.417, count=48
# family: similarity=0.403, count=12
# who: similarity=0.426, count=23
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Mom: similarity=0.433, count=6
# Where: similarity=0.444, count=17
# kids: similarity=0.627, count=8
# old: similarity=0.410, count=20
# Who: similarity=0.426, count=13
# old: similarity=0.410, count=20
# girls: similarity=0.568, count=9
# old: similarity=0.410, count=20
# HOUSE: similarity=0.417, count=48
# He: similarity=0.426, count=244
# There: similarity=0.425, count=18
# They: similarity=0.410, count=45
# He: similarity=0.426, count=244
# he: similarity=0.426, count=70
# He: similarity=0.426, count=244
# still: similarity=0.408, count=23
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# still: similarity=0.408, count=23
# up: similarity=0.423, count=166
# he: similarity=0.426, count=70
# up: similarity=0.423, count=166
# Where: similarity=0.444, count=17
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# church: similarity=0.510, count=11
# church: similarity=0.510, count=11
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Her: similarity=0.420, count=19
# came: similarity=0.414, count=7
# early: similarity=0.404, count=4
# her: similarity=0.420, count=373
# went: similarity=0.468, count=2
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# took: similarity=0.425, count=4
# CHURCH: similarity=0.510, count=31
# TIME: similarity=0.425, count=2
# up: similarity=0.423, count=166
# parents: similarity=0.586, count=12
# still: similarity=0.408, count=23
# She: similarity=0.461, count=304
# he: similarity=0.426, count=70
# There: similarity=0.425, count=18
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# studies: similarity=0.406, count=4
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# studies: similarity=0.406, count=4
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Her: similarity=0.420, count=19
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# Mom: similarity=0.433, count=6
# still: similarity=0.408, count=23
# remember: similarity=0.423, count=8
# where: similarity=0.444, count=6
# still: similarity=0.408, count=23
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# he: similarity=0.426, count=70
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# Where: similarity=0.444, count=17
# where: similarity=0.444, count=6
# who: similarity=0.426, count=23
# He: similarity=0.426, count=244
# Got: similarity=0.406, count=3
# junior: similarity=0.545, count=1
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# course: similarity=0.502, count=4
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# family: similarity=0.403, count=12
# gone: similarity=0.418, count=3
# years: similarity=0.439, count=3
# studies: similarity=0.406, count=4
# boys: similarity=0.588, count=15
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# HOUSE: similarity=0.417, count=48
# He: similarity=0.426, count=244
# HOUSE: similarity=0.417, count=48
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# he: similarity=0.426, count=70
# when: similarity=0.441, count=9
# He: similarity=0.426, count=244
# Go: similarity=0.440, count=4
# way: similarity=0.416, count=12
# up: similarity=0.423, count=166
# girl: similarity=0.476, count=27
# She: similarity=0.461, count=304
# Where: similarity=0.444, count=17
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# church: similarity=0.510, count=11
# She: similarity=0.461, count=304
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# they: similarity=0.410, count=28
# Friends: similarity=0.432, count=1
# CHURCH: similarity=0.510, count=31
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# high: similarity=0.542, count=5
# She: similarity=0.461, count=304
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# first: similarity=0.400, count=11
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# everyone: similarity=0.408, count=2
# care: similarity=0.414, count=3
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# They: similarity=0.410, count=45
# her: similarity=0.420, count=373
# who: similarity=0.426, count=23
# CHURCH: similarity=0.510, count=31
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# up: similarity=0.423, count=166
# CHURCH: similarity=0.510, count=31
# she: similarity=0.461, count=105
# got: similarity=0.406, count=38
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# They: similarity=0.410, count=45
# There: similarity=0.425, count=18
# life: similarity=0.408, count=8
# remember: similarity=0.423, count=8
# went: similarity=0.468, count=2
# freshman: similarity=0.512, count=11
# when: similarity=0.441, count=9
# freshman: similarity=0.512, count=11
# but: similarity=0.405, count=26
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# church: similarity=0.510, count=11
# there: similarity=0.425, count=16
# going: similarity=0.450, count=38
# there: similarity=0.425, count=16
# high: similarity=0.542, count=5
# school: similarity=1.000, count=13
# he: similarity=0.426, count=70
# girl: similarity=0.476, count=27
# she: similarity=0.461, count=105
# got: similarity=0.406, count=38
# got: similarity=0.406, count=38
# her: similarity=0.420, count=373
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# go: similarity=0.440, count=37
# He: similarity=0.426, count=244
# learn: similarity=0.415, count=2
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# going: similarity=0.450, count=38
# He: similarity=0.426, count=244
# They: similarity=0.410, count=45
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# he: similarity=0.426, count=70
# still: similarity=0.408, count=23
# she: similarity=0.461, count=105
# years: similarity=0.439, count=3
# her: similarity=0.420, count=373
# There: similarity=0.425, count=18
# first: similarity=0.400, count=11
# time: similarity=0.425, count=20
# going: similarity=0.450, count=38
# But: similarity=0.405, count=14
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# he: similarity=0.426, count=70
# He: similarity=0.426, count=244
# CHURCH: similarity=0.510, count=31
# CHURCH: similarity=0.510, count=31
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# her: similarity=0.420, count=373
# There: similarity=0.425, count=18
# going: similarity=0.450, count=38
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# CHURCH: similarity=0.510, count=31
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# They: similarity=0.410, count=45
# CHURCH: similarity=0.510, count=31
# CHURCH: similarity=0.510, count=31
# They: similarity=0.410, count=45
# past: similarity=0.451, count=6
# parents: similarity=0.586, count=12
# CHURCH: similarity=0.510, count=31
# CHURCH: similarity=0.510, count=31
# her: similarity=0.420, count=373
# Go: similarity=0.440, count=4
# He: similarity=0.426, count=244
# CHURCH: similarity=0.510, count=31
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# CHURCH: similarity=0.510, count=31
# time: similarity=0.425, count=20
# they: similarity=0.410, count=28
# CHURCH: similarity=0.510, count=31
# He: similarity=0.426, count=244
# CHURCH: similarity=0.510, count=31
# families: similarity=0.404, count=1
# church: similarity=0.510, count=11
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# CHURCH: similarity=0.510, count=31
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# church: similarity=0.510, count=11
# CHURCH: similarity=0.510, count=31
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# CHURCH: similarity=0.510, count=31
# she: similarity=0.461, count=105
# Who: similarity=0.426, count=13
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# going: similarity=0.450, count=38
# kids: similarity=0.627, count=8
# old: similarity=0.410, count=20
# she: similarity=0.461, count=105
# old: similarity=0.410, count=20
# old: similarity=0.410, count=20
# up: similarity=0.423, count=166
# old: similarity=0.410, count=20
# He: similarity=0.426, count=244
# old: similarity=0.410, count=20
# They: similarity=0.410, count=45
# old: similarity=0.410, count=20
# CHURCH: similarity=0.510, count=31
# church: similarity=0.510, count=11
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# church: similarity=0.510, count=11
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# girl: similarity=0.476, count=27
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# Her: similarity=0.420, count=19
# She: similarity=0.461, count=304
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# HER: similarity=0.420, count=6
# church: similarity=0.510, count=11
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# she: similarity=0.461, count=105
# he: similarity=0.426, count=70
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# her: similarity=0.420, count=373
# he: similarity=0.426, count=70
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# He: similarity=0.426, count=244
# he: similarity=0.426, count=70
# He: similarity=0.426, count=244
# Her: similarity=0.420, count=19
# She: similarity=0.461, count=304
# She: similarity=0.461, count=304
# He: similarity=0.426, count=244
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# church: similarity=0.510, count=11
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# He: similarity=0.426, count=244
# they: similarity=0.410, count=28
# doing: similarity=0.404, count=8
# came: similarity=0.414, count=7
# go: similarity=0.440, count=37
# He: similarity=0.426, count=244
# going: similarity=0.450, count=38
# old: similarity=0.410, count=20
# He: similarity=0.426, count=244
# She: similarity=0.461, count=304
# he: similarity=0.426, count=70
# her: similarity=0.420, count=373
# life: similarity=0.408, count=8
# he: similarity=0.426, count=70
# boy: similarity=0.480, count=12
# He: similarity=0.426, count=244
# up: similarity=0.423, count=166
# up: similarity=0.423, count=166
# taking: similarity=0.402, count=4
# her: similarity=0.420, count=373
# She: similarity=0.461, count=304
# CLUB: similarity=0.431, count=2
# He: similarity=0.426, count=244
# where: similarity=0.444, count=6
# He: similarity=0.426, count=244
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# she: similarity=0.461, count=105
# She: similarity=0.461, count=304
# she: similarity=0.461, count=105
# still: similarity=0.408, count=23
# her: similarity=0.420, count=373
# her: similarity=0.420, count=373
# Mom: similarity=0.433, count=6
# up: similarity=0.423, count=166
# her: similarity=0.420, count=373
# home: similarity=0.445, count=9
# her: similarity=0.420, count=373
# house: similarity=0.417, count=34
# family: similarity=0.403, count=12
# club: similarity=0.431, count=6
# HOUSE: similarity=0.417, count=48
# They: similarity=0.410, count=45
# He: similarity=0.426, count=244
# her: similarity=0.420, count=373
# came: similarity=0.414, count=7
# up: similarity=0.423, count=166

# %% [markdown]
# ## Your Turn!
#
# Adapt this code in your own Python file or notebook to explore similarity values based on your own collection of text files. Is this of interest in your project?
